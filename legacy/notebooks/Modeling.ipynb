# %%
# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import polars as pl

# x = requests.get('https://api.opendota.com/api/publicMatches', params={'less_than_match_id':7075980402})

# %%
# from tqdm import tqdm

# df = pl.read_parquet('../DATA/tmp_03.20.2023.10.08.35.parquet').to_pandas()
# SET = set()
# for idx, row in tqdm(df.iterrows()):
#     SET.update(row['winner_team'])

# TRANSFORM = {hero_id : idx + 1 for idx, hero_id in enumerate(list(SET))}
# TRANSFORM

# %%
df = pl.read_parquet("DATA/tmp_15_nov_25.parquet")
df = df.with_columns(
    pl.col("avg_rank_tier")
    .map_elements(lambda x: min(5, x // 10 - 1), return_dtype=pl.Int64)
    .alias("avg_rank_tier"),
    pl.when("radiant_win")
    .then("radiant_team")
    .otherwise("dire_team")
    .alias("winner_team"),
    pl.when("radiant_win")
    .then("dire_team")
    .otherwise("radiant_team")
    .alias("loser_team"),
).drop(["dire_team", "radiant_team", "radiant_win"])
DICTS = df.to_dicts()

# %%
df
# Out:
# shape: (2_778_243, 8)
# ┌────────────┬────────────┬──────────┬────────────┬───────────┬────────────┬───────────┬───────────┐
# │ match_id   ┆ match_seq_ ┆ duration ┆ start_time ┆ game_mode ┆ avg_rank_t ┆ winner_te ┆ loser_tea │
# │ ---        ┆ num        ┆ ---      ┆ ---        ┆ ---       ┆ ier        ┆ am        ┆ m         │
# │ i64        ┆ ---        ┆ i64      ┆ i64        ┆ i64       ┆ ---        ┆ ---       ┆ ---       │
# │            ┆ i64        ┆          ┆            ┆           ┆ i64        ┆ list[i64] ┆ list[i64] │
# ╞════════════╪════════════╪══════════╪════════════╪═══════════╪════════════╪═══════════╪═══════════╡
# │ 8516695910 ┆ 7153484301 ┆ 2816     ┆ 1760782739 ┆ 22        ┆ 2          ┆ [94, 112, ┆ [70, 91,  │
# │            ┆            ┆          ┆            ┆           ┆            ┆ … 2]      ┆ … 21]     │
# │ 8516695613 ┆ 7153477697 ┆ 2463     ┆ 1760782739 ┆ 22        ┆ 3          ┆ [14, 72,  ┆ [8, 83, … │
# │            ┆            ┆          ┆            ┆           ┆            ┆ … 27]     ┆ 138]      │
# │ 8516695614 ┆ 7153471005 ┆ 2101     ┆ 1760782739 ┆ 22        ┆ 5          ┆ [86, 120, ┆ [21, 52,  │
# │            ┆            ┆          ┆            ┆           ┆            ┆ … 84]     ┆ … 33]     │
# │ 8516695606 ┆ 7153467124 ┆ 1864     ┆ 1760782739 ┆ 22        ┆ 1          ┆ [70, 8, … ┆ [129, 53, │
# │            ┆            ┆          ┆            ┆           ┆            ┆ 30]       ┆ … 11]     │
# │ 8516695616 ┆ 7153461225 ┆ 1552     ┆ 1760782739 ┆ 22        ┆ 5          ┆ [64, 36,  ┆ [75, 135, │
# │            ┆            ┆          ┆            ┆           ┆            ┆ … 100]    ┆ … 111]    │
# │ …          ┆ …          ┆ …        ┆ …          ┆ …         ┆ …          ┆ …         ┆ …         │
# │ 8559599113 ┆ 7189199131 ┆ 1117     ┆ 1763200943 ┆ 22        ┆ 2          ┆ [106,     ┆ [128, 86, │
# │            ┆            ┆          ┆            ┆           ┆            ┆ 101, …    ┆ … 79]     │
# │            ┆            ┆          ┆            ┆           ┆            ┆ 48]       ┆           │
# │ 8559599214 ┆ 7189196571 ┆ 999      ┆ 1763200948 ┆ 4         ┆ 1          ┆ [70, 31,  ┆ [76, 8, … │
# │            ┆            ┆          ┆            ┆           ┆            ┆ … 66]     ┆ 17]       │
# │ 8559600216 ┆ 7189199567 ┆ 1098     ┆ 1763200993 ┆ 22        ┆ 4          ┆ [9, 48, … ┆ [39, 128, │
# │            ┆            ┆          ┆            ┆           ┆            ┆ 59]       ┆ … 5]      │
# │ 8559602910 ┆ 7189199155 ┆ 965      ┆ 1763201112 ┆ 22        ┆ 5          ┆ [48, 107, ┆ [54, 102, │
# │            ┆            ┆          ┆            ┆           ┆            ┆ … 104]    ┆ … 9]      │
# │ 8559603116 ┆ 7189199861 ┆ 959      ┆ 1763201133 ┆ 22        ┆ 5          ┆ [2, 20, … ┆ [7, 104,  │
# │            ┆            ┆          ┆            ┆           ┆            ┆ 8]        ┆ … 49]     │
# └────────────┴────────────┴──────────┴────────────┴───────────┴────────────┴───────────┴───────────┘

# %%
df["game_mode"].value_counts()
# Out:
# shape: (8, 2)
# ┌───────────┬─────────┐
# │ game_mode ┆ count   │
# │ ---       ┆ ---     │
# │ i64       ┆ u32     │
# ╞═══════════╪═════════╡
# │ 2         ┆ 7235    │
# │ 3         ┆ 22373   │
# │ 22        ┆ 2646356 │
# │ 12        ┆ 2       │
# │ 16        ┆ 110     │
# │ 5         ┆ 8       │
# │ 1         ┆ 34      │
# │ 4         ┆ 102125  │
# └───────────┴─────────┘

# %%
TEST_DICTS = DICTS[-len(DICTS) // 20 :]
TRAIN_DICTS = DICTS[: -len(DICTS) // 20]
len(TRAIN_DICTS), len(TEST_DICTS)
# Out:
# (2639330, 138913)

# %%
from picker.model.dataset import TeamDataset

# %%
# from tqdm import tqdm

# df = pl.read_parquet('../DATA/tmp_03.20.2023.10.08.35.parquet').to_pandas()
# SET = set()
# for idx, row in tqdm(df.iterrows()):
#     SET.update(row['winner_team'])

# TRANSFORM = {hero_id : idx + 1 for idx, hero_id in enumerate(list(SET))}
# TRANSFORM

# %%
train_data = TeamDataset("", dicts_override=TRAIN_DICTS, p=0.2)
test_data1 = TeamDataset("", dicts_override=TEST_DICTS, p=0.0)
test_data2 = TeamDataset("", dicts_override=TEST_DICTS, p=0.2)

# %%
from picker.model.training_model import run_training
from picker.model.transformer import TransformerModel
from picker.model.constants import HERO_TRANSFORM

# %%
# embedding_dict = {'team': [len(HERO_TRANSFORM) + 1, 15], 'enemy': [len(HERO_TRANSFORM) + 1, 32]}
embedding_dict = {"team": [len(HERO_TRANSFORM) + 1, 32 - 3 - 1], "rank": [6, 3]}
model = TransformerModel(
    embedding_dict=embedding_dict,
    num_heads=8,
    num_layers=6,
)

# %%
from torch.nn import CrossEntropyLoss
import torch

run_training(
    model=model,
    name="trans-32-0.2-v2",
    train_data=train_data,
    test_datas=[test_data1, test_data2],
    optimizer=torch.optim.Adam(model.parameters(), lr=3e-4),
    criterion=CrossEntropyLoss(),
    epochs=100,
    batch_size=1024 * 8,
    device="cuda",
)
# Out:
# saved model to `trans-32-0.2-v2.pth`

# %%
torch.save(model.state_dict(), "zhopa2.pth")

# %%
# %debug
# Out:
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/_utils.py(543)reraise()
#     541             # instantiate since we don't know how to
#     542             raise RuntimeError(msg) from None
# --> 543         raise exception
#     544
#     545
# ipdb>  u
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py(1359)_process_data()
#    1357         self._try_put_index()
#    1358         if isinstance(data, ExceptionWrapper):
# -> 1359             data.reraise()
#    1360         return data
#    1361
# ipdb>  u
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py(1333)_next_data()
#    1331             else:
#    1332                 del self._task_info[idx]
# -> 1333                 return self._process_data(data)
#    1334
#    1335     def _try_put_index(self):
# ipdb>  u
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py(628)__next__()
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
# ipdb>  u
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/tqdm/std.py(1195)__iter__()
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
#    1196                 yield obj
#    1197                 # Update and possibly print the progressbar.
# ipdb>  u
# > /mnt/d/Git_shit_2/shad_courses/picker/picker/model/training_model.py(14)train()
#      12     optimizer.zero_grad()
#      13
# ---> 14     for idx, (X, y) in enumerate(tqdm(train_dl, total=len(train_dl), desc="Train...")):
#      15         if isinstance(X, torch.Tensor):
#      16             X = X.to(device)
# ipdb>  u
# > /mnt/d/Git_shit_2/shad_courses/picker/picker/model/training_model.py(100)run_training()
#      98
#      99     for epoch in range(epochs):
# --> 100         loss_log = train(
#     101             model=model,
#     102             train_dl=train_dl,
# ipdb>  u
# > /tmp/ipykernel_56155/687358011.py(4)<module>()
#       2 import torch
#       3
# ----> 4 run_training(model=model, name='trans-32-0.2-v2', train_data=train_data, test_datas=[test_data1, test_data2],
#       5              optimizer=torch.optim.Adam(model.parameters(), lr=3e-4),
#       6              criterion=CrossEntropyLoss(),
# ipdb>  d
# > /mnt/d/Git_shit_2/shad_courses/picker/picker/model/training_model.py(100)run_training()
#      98
#      99     for epoch in range(epochs):
# --> 100         loss_log = train(
#     101             model=model,
#     102             train_dl=train_dl,
# ipdb>  d
# > /mnt/d/Git_shit_2/shad_courses/picker/picker/model/training_model.py(14)train()
#      12     optimizer.zero_grad()
#      13
# ---> 14     for idx, (X, y) in enumerate(tqdm(train_dl, total=len(train_dl), desc="Train...")):
#      15         if isinstance(X, torch.Tensor):
#      16             X = X.to(device)
# ipdb>  d
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/tqdm/std.py(1195)__iter__()
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
#    1196                 yield obj
#    1197                 # Update and possibly print the progressbar.
# ipdb>  d
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py(628)__next__()
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
# ipdb>  d
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py(1333)_next_data()
#    1331             else:
#    1332                 del self._task_info[idx]
# -> 1333                 return self._process_data(data)
#    1334
#    1335     def _try_put_index(self):
# ipdb>  d
# > /home/qc7/.cache/pypoetry/virtualenvs/picker-aqmUO_25-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py(1359)_process_data()
#    1357         self._try_put_index()
#    1358         if isinstance(data, ExceptionWrapper):
# -> 1359             data.reraise()
#    1360         return data
#    1361
# ipdb>  exit

# %%
import torch
from picker.model.transformer import TransformerModel
from picker.model.constants import HERO_TRANSFORM

embedding_dict = {"team": [len(HERO_TRANSFORM) + 1, 32 - 3 - 1], "rank": [6, 3]}
model = TransformerModel(
    embedding_dict=embedding_dict,
    num_heads=8,
    num_layers=6,
)
model.load_state_dict(torch.load("zhopa2.pth"))

model.to("cpu")
model.eval()
pass

# %%
# script = torch.jit.script(model)
torch.save(model, "zhopa2.raw_model")

# %%
# %%time

for HERO in HERO_TRANSFORM.values():
], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4989, 0.5011]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5063, 0.4937]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4668, 0.5332]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4668, 0.5332]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5388, 0.4612]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5302, 0.4698]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5302, 0.4698]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4679, 0.5321]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5167, 0.4833]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5167, 0.4833]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4921, 0.5079]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5197, 0.4803]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5197, 0.4803]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4867, 0.5133]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4919, 0.5081]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4919, 0.5081]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5088, 0.4912]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5123, 0.4877]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5123, 0.4877]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4920, 0.5080]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5047, 0.4953]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5047, 0.4953]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5049, 0.4951]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5672, 0.4328]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5672, 0.4328]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4343, 0.5657]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5158, 0.4842]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5158, 0.4842]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4865, 0.5135]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5009, 0.4991]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5009, 0.4991]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5038, 0.4962]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4844, 0.5156]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4844, 0.5156]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5251, 0.4749]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4767, 0.5233]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4767, 0.5233]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5309, 0.4691]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4885, 0.5115]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4885, 0.5115]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5186, 0.4814]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5397, 0.4603]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5397, 0.4603]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4642, 0.5358]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5112, 0.4888]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5112, 0.4888]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4944, 0.5056]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4964, 0.5036]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4964, 0.5036]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5072, 0.4928]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5122, 0.4878]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5122, 0.4878]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4906, 0.5094]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5330, 0.4670]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5330, 0.4670]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4713, 0.5287]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5053, 0.4947]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5053, 0.4947]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5049, 0.4951]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4657, 0.5343]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4657, 0.5343]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5431, 0.4569]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4814, 0.5186]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4814, 0.5186]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5208, 0.4792]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4954, 0.5046]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4954, 0.5046]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5145, 0.4855]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5618, 0.4382]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5618, 0.4382]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4457, 0.5543]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5089, 0.4911]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5089, 0.4911]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4989, 0.5011]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5422, 0.4578]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5422, 0.4578]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4572, 0.5428]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5124, 0.4876]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5124, 0.4876]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4875, 0.5125]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5243, 0.4757]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5243, 0.4757]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4736, 0.5264]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4986, 0.5014]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4986, 0.5014]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5048, 0.4952]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5028, 0.4972]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5028, 0.4972]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5052, 0.4948]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5193, 0.4807]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5193, 0.4807]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4789, 0.5211]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.4893, 0.5107]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4893, 0.5107]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5187, 0.4813]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5116, 0.4884]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5116, 0.4884]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4841, 0.5159]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5167, 0.4833]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5167, 0.4833]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4899, 0.5101]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5374, 0.4626]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5374, 0.4626]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4690, 0.5310]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5230, 0.4770]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5230, 0.4770]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4762, 0.5238]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# tensor([[0.5353, 0.4647]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.5353, 0.4647]], grad_fn=<SoftmaxBackward0>)
#  tensor([[0.4696, 0.5304]], grad_fn=<SoftmaxBackward0>)
# ------------------------------------------------------------
# CPU times: user 12.1 s, sys: 26.2 ms, total: 12.1 s
# Wall time: 1.04 s

# %%
len(HERO_TRANSFORM)
# Out:
# 127

# %%
# %debug
# Out:
# > /home/yarik/shad/picker/picker/model/training_model.py(57)plot_stuff()
#      55     if len(accs):
#      56         for idx in range(accs_np.shape[1]):
# ---> 57             ax2.plot(accs[:, idx], label = f'Test dataset number {idx}')
#      58
#      59     ax2.set_title("Accs on test")
#
# ipdb> idx
# 0
# ipdb> accs[:, idx]
# *** TypeError: list indices must be integers or slices, not tuple

# %%
import torch

A = torch.cat((torch.ones(512, 5, 1), torch.zeros(512, 5, 1)), dim=-2)

# %%
torch.cat((torch.rand(512, 10, 63), A), dim=-1).shape
# Out:
# torch.Size([512, 10, 64])

# %%
emb = torch.cat(embs).reshape(1, 10, -1)
res = model(emb, None)

# %%
res
# Out:
# tensor([[0.4648]], grad_fn=<AddmmBackward0>)

# %%
a = torch.rand(1, 10, 64)
b = torch.rand(1, 1, 64)

# %%
torch.cat((a, b), dim=1)
# Out:
# tensor([[[0.0823, 0.2277, 0.4079, 0.9386, 0.0742, 0.7202, 0.3607, 0.9005,
#           0.1608, 0.2063, 0.7980, 0.9442, 0.0333, 0.5649, 0.2936, 0.4545,
#           0.4625, 0.3905, 0.5795, 0.6908, 0.0839, 0.7522, 0.9392, 0.1067,
#           0.3177, 0.5344, 0.1385, 0.7366, 0.2210, 0.7947, 0.2109, 0.0716,
#           0.8087, 0.5818, 0.2675, 0.9628, 0.7965, 0.6796, 0.1220, 0.6453,
#           0.2468, 0.2309, 0.3061, 0.2880, 0.1987, 0.7911, 0.5555, 0.4565,
#           0.8999, 0.4815, 0.6246, 0.6285, 0.7902, 0.0816, 0.5806, 0.1977,
#           0.6592, 0.5274, 0.3737, 0.8188, 0.5043, 0.8749, 0.7966, 0.2408],
#          [0.9915, 0.3214, 0.3582, 0.4512, 0.1294, 0.6715, 0.8483, 0.3055,
#           0.6333, 0.0336, 0.1905, 0.7927, 0.0481, 0.4222, 0.6530, 0.4618,
#           0.4607, 0.9218, 0.1592, 0.9127, 0.1080, 0.6349, 0.9745, 0.8846,
#           0.1505, 0.5538, 0.9617, 0.9514, 0.5724, 0.8122, 0.7971, 0.8665,
#           0.4984, 0.1422, 0.6348, 0.0502, 0.9907, 0.4200, 0.7669, 0.3436,
#           0.3604, 0.8022, 0.5990, 0.7234, 0.7494, 0.0636, 0.9351, 0.0980,
#           0.0789, 0.2025, 0.9868, 0.8937, 0.0378, 0.8142, 0.0284, 0.4992,
#           0.1438, 0.5016, 0.7600, 0.4765, 0.3734, 0.1405, 0.7795, 0.0251],
#          [0.5293, 0.2018, 0.0844, 0.1540, 0.4002, 0.0924, 0.3899, 0.0934,
#           0.9307, 0.3287, 0.7514, 0.4496, 0.7419, 0.9695, 0.0035, 0.2762,
#           0.4364, 0.1528, 0.5141, 0.1903, 0.7141, 0.2052, 0.9015, 0.6373,
#           0.7493, 0.2597, 0.1370, 0.8378, 0.6878, 0.5573, 0.7830, 0.4222,
#           0.5416, 0.4588, 0.3011, 0.6952, 0.1071, 0.0123, 0.3640, 0.8499,
#           0.2097, 0.8281, 0.0107, 0.8978, 0.5376, 0.9874, 0.0979, 0.5948,
#           0.2382, 0.4197, 0.8722, 0.6351, 0.3813, 0.6243, 0.4186, 0.9045,
#           0.9252, 0.7115, 0.0873, 0.0066, 0.2528, 0.5448, 0.1491, 0.0279],
#          [0.6541, 0.7755, 0.9124, 0.2386, 0.9303, 0.6394, 0.6280, 0.2859,
#           0.3803, 0.4762, 0.2397, 0.4504, 0.5789, 0.6026, 0.5671, 0.6471,
#           0.6757, 0.9011, 0.4261, 0.6587, 0.5551, 0.4626, 0.3373, 0.5324,
