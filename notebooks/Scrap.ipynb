# %%
import requests
import orjson 
import pandas as pd 
import polars as pl
from time import sleep

# x = requests.get('https://api.opendota.com/api/publicMatches', params={'less_than_match_id':7075980402})

# %%
df = pl.read_parquet('data/tmp_03.20.2023.10.08.35.parquet')

# %%
df
# Out:
# shape: (1199144, 10)
# ┌─────────────┬────────────┬───────────┬──────────┬─────┬─────────┬──────┬───────────┬─────────────┐
# │ match_id    ┆ match_seq_ ┆ game_mode ┆ start_ti ┆ ... ┆ avg_mmr ┆ bans ┆ winner_te ┆ loser_team  │
# │ ---         ┆ num        ┆ ---       ┆ me       ┆     ┆ ---     ┆ ---  ┆ am        ┆ ---         │
# │ i64         ┆ ---        ┆ i64       ┆ ---      ┆     ┆ f64     ┆ i8   ┆ ---       ┆ list[i64]   │
# │             ┆ i64        ┆           ┆ i64      ┆     ┆         ┆      ┆ list[i64] ┆             │
# ╞═════════════╪════════════╪═══════════╪══════════╪═════╪═════════╪══════╪═══════════╪═════════════╡
# │ 7069218302  ┆ 5936308834 ┆ 22        ┆ 16793069 ┆ ... ┆ 3713.0  ┆ null ┆ [73, 135, ┆ [42, 71,    │
# │             ┆            ┆           ┆ 60       ┆     ┆         ┆      ┆ ... 44]   ┆ ... 121]    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7069219414  ┆ 5936310645 ┆ 22        ┆ 16793070 ┆ ... ┆ 3273.0  ┆ null ┆ [1, 26,   ┆ [104, 9,    │
# │             ┆            ┆           ┆ 20       ┆     ┆         ┆      ┆ ... 16]   ┆ ... 22]     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7069218516  ┆ 5936310704 ┆ 22        ┆ 16793069 ┆ ... ┆ 5102.0  ┆ null ┆ [87, 23,  ┆ [14, 138,   │
# │             ┆            ┆           ┆ 75       ┆     ┆         ┆      ┆ ... 32]   ┆ ... 44]     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7069230106  ┆ 5936311144 ┆ 22        ┆ 16793076 ┆ ... ┆ null    ┆ null ┆ [86, 11,  ┆ [13, 104,   │
# │             ┆            ┆           ┆ 92       ┆     ┆         ┆      ┆ ... 64]   ┆ ... 14]     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...         ┆ ...        ┆ ...       ┆ ...      ┆ ... ┆ ...     ┆ ...  ┆ ...       ┆ ...         │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7090349805  ┆ 5955042658 ┆ 22        ┆ 16805176 ┆ ... ┆ 2557.0  ┆ null ┆ [21, 136, ┆ [84, 56,    │
# │             ┆            ┆           ┆ 12       ┆     ┆         ┆      ┆ ... 105]  ┆ ... 129]    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7090357403  ┆ 5955046785 ┆ 22        ┆ 16805180 ┆ ... ┆ null    ┆ null ┆ [15, 50,  ┆ [2, 128,    │
# │             ┆            ┆           ┆ 88       ┆     ┆         ┆      ┆ ... 97]   ┆ ... 34]     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7090357311  ┆ 5955043342 ┆ 22        ┆ 16805180 ┆ ... ┆ 3208.0  ┆ null ┆ [96, 86,  ┆ [41, 137,   │
# │             ┆            ┆           ┆ 82       ┆     ┆         ┆      ┆ ... 113]  ┆ ... 7]      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7090361209  ┆ 5955464388 ┆ 22        ┆ 16805183 ┆ ... ┆ 2617.0  ┆ null ┆ [11, 19,  ┆ [36, 5, ... │
# │             ┆            ┆           ┆ 14       ┆     ┆         ┆      ┆ ... 10]   ┆ 8]          │
# └─────────────┴────────────┴───────────┴──────────┴─────┴─────────┴──────┴───────────┴─────────────┘

# %%
import datetime

# %%
dt = datetime.datetime.now()

# %%
'%27' + dt.strftime('%Y-%M-%dT%H') + '%3A' + dt.strftime('%M') + '%3A' + dt.strftime('%S.000Z') + '%27'
# Out:
# '%272023-39-03T19%3A39%3A15.000Z%27'

# %%
'%272023-02-27T12%3A29%3A08.991Z%27'
# Out:
# '%272023-02-27T12%3A29%3A08.991Z%27'

# %%
leftTimestampBorder = '%272023-02-27T12%3A29%3A08.000Z%27'
rightTimestampBorder = '%272023-02-27T13%3A29%3A08.000Z%27'
matchesCount = 500000

# %%
reqreq = f"""https://api.opendota.com/api/explorer?sql=SELECT%0Ajson_agg(m)%20matches
%0AFROM%20(%0A%20%20SELECT%20match_id%2C%20num_mmr%2C%0A%20%20
(%0A%20%20%20%20SELECT%20json_agg(p)%0A%20%20%20%20FROM%20
(%0A%20%20%20%20%20%20SELECT%20hero_id%2C%20((player_slot%20%3C%20128)
%20%3D%20public_matches.radiant_win)%20win%0A%20%20%20%20%20%20FROM%20
public_player_matches%0A%20%20%20%20%20%20WHERE%20true
%20%0A%20%20%20%20%20%20AND%20match_id%20%3D%20public_matches.match_id
%20%0A%20%20%20%20)%20p%0A%20%20)%20players%0A%20%20FROM%20public_matches
%20%0A%20%20WHERE%20TRUE%20%0A%20%20AND%20start_time%20%3E%20
extract(epoch%20from%20timestamp%20{leftTimestampBorder})
%0A%20%20AND%20start_time%20%3C%20
extract(epoch%20from%20timestamp%20{rightTimestampBorder})
%0A%20%20AND%20duration%20%3E%201200%20%0A%20%20
AND%20game_mode%20%3D%2022%0A%20%20AND%20num_mmr%20IS%20NOT%20NULL
%0A%20%20LIMIT%20{matchesCount})%20m""".replace('\n', '')

# %%
reqreq = f"""https://api.opendota.com/api/explorer?sql=SELECT%0Ajson_agg(m)%20matches
%0AFROM%20(%0A%20%20SELECT%20match_id%2C%20num_mmr%2C%20match_seq_num%2C%20duration
%2C%20start_time%2C%20game_mode%2C%20avg_mmr%2C
%20avg_rank_tier%2C%0A%20%20
(%0A%20%20%20%20SELECT%20json_agg(p)%0A%20%20%20%20FROM%20
(%0A%20%20%20%20%20%20SELECT%20hero_id%2C%20((player_slot%20%3C%20128)
%20%3D%20public_matches.radiant_win)%20win%0A%20%20%20%20%20%20FROM%20
public_player_matches%0A%20%20%20%20%20%20WHERE%20true
%20%0A%20%20%20%20%20%20AND%20match_id%20%3D%20public_matches.match_id
%20%0A%20%20%20%20)%20p%0A%20%20)%20players%0A%20%20FROM%20public_matches
%20%0A%20%20WHERE%20TRUE%20%0A%20%20AND%20start_time%20%3E%20
extract(epoch%20from%20timestamp%20{leftTimestampBorder})
%0A%20%20AND%20start_time%20%3C%20
extract(epoch%20from%20timestamp%20{rightTimestampBorder})
%0A%20%20AND%20duration%20%3E%20900%20%0A%20%20
%0A%20%20LIMIT%20{matchesCount})%20m""".replace('\n', '')

# %%
reqreq
# Out:
# 'https://api.opendota.com/api/explorer?sql=SELECT%0Ajson_agg(m)%20matches%0AFROM%20(%0A%20%20SELECT%20match_id%2C%20num_mmr%2C%20match_seq_num%2C%20duration%2C%20start_time%2C%20game_mode%2C%20avg_mmr%2C%20avg_rank_tier%2C%0A%20%20(%0A%20%20%20%20SELECT%20json_agg(p)%0A%20%20%20%20FROM%20(%0A%20%20%20%20%20%20SELECT%20hero_id%2C%20((player_slot%20%3C%20128)%20%3D%20public_matches.radiant_win)%20win%0A%20%20%20%20%20%20FROM%20public_player_matches%0A%20%20%20%20%20%20WHERE%20true%20%0A%20%20%20%20%20%20AND%20match_id%20%3D%20public_matches.match_id%20%0A%20%20%20%20)%20p%0A%20%20)%20players%0A%20%20FROM%20public_matches%20%0A%20%20WHERE%20TRUE%20%0A%20%20AND%20start_time%20%3E%20extract(epoch%20from%20timestamp%20%272023-02-27T12%3A29%3A08.000Z%27)%0A%20%20AND%20start_time%20%3C%20extract(epoch%20from%20timestamp%20%272023-02-27T13%3A29%3A08.000Z%27)%0A%20%20AND%20duration%20%3E%20900%20%0A%20%20%0A%20%20LIMIT%20500000)%20m'

# %%
x = requests.get(reqreq)

# %%
x.status_code
# Out:
# 200

# %%
x.text
# Out:
# '{"command":"SELECT","rowCount":1,"oid":null,"rows":[{"matches":[{"match_id":7036473018,"num_mmr":null,"match_seq_num":5907608475,"duration":1566,"start_time":1677501034,"game_mode":4,"avg_mmr":null,"avg_rank_tier":44,"players":[{"hero_id":101,"win":true},{"hero_id":71,"win":true},{"hero_id":86,"win":true},{"hero_id":112,"win":true},{"hero_id":136,"win":true},{"hero_id":42,"win":false},{"hero_id":4,"win":false},{"hero_id":22,"win":false},{"hero_id":114,"win":false},{"hero_id":41,"win":false}]},{"match_id":7036474202,"num_mmr":1,"match_seq_num":5907609183,"duration":1544,"start_time":1677501098,"game_mode":22,"avg_mmr":1219,"avg_rank_tier":31,"players":[{"hero_id":67,"win":false},{"hero_id":27,"win":false},{"hero_id":93,"win":false},{"hero_id":13,"win":false},{"hero_id":33,"win":false},{"hero_id":19,"win":true},{"hero_id":47,"win":true},{"hero_id":41,"win":true},{"hero_id":9,"win":true},{"hero_id":50,"win":true}]},{"match_id":7036471703,"num_mmr":1,"match_seq_num":5907609568,"duration":1632,"start_time":1677500992,"game_mode":22,"avg_mmr":1497,"avg_rank_tier":55,"players":[{"hero_id":50,"win":false},{"hero_id":20,"win":false},{"hero_id":2,"win":false},{"hero_id":109,"win":false},{"hero_id":106,"win":false},{"hero_id":34,"win":true},{"hero_id":97,"win":true},{"hero_id":85,"win":true},{"hero_id":35,"win":true},{"hero_id":123,"win":true}]},{"match_id":7036471903,"num_mmr":null,"match_seq_num":5907612920,"duration":1810,"start_time":1677501003,"game_mode":22,"avg_mmr":null,"avg_rank_tier":21,"players":[{"hero_id":44,"win":false},{"hero_id":64,"win":false},{"hero_id":25,"win":false},{"hero_id":123,"win":false},{"hero_id":19,"win":false},{"hero_id":86,"win":true},{"hero_id":29,"win":true},{"hero_id":50,"win":true},{"hero_id":93,"win":true},{"hero_id":59,"win":true}]},{"match_id":7036475615,"num_mmr":1,"match_seq_num":5907615527,"duration":1873,"start_time":1677501139,"game_mode":5,"avg_mmr":3207,"avg_rank_tier":42,"players":[{"hero_id":56,"win":true},{"hero_id":87,"win":true},{"hero_id":52,"win":true},{"hero_id":15,"win":true},{"hero_id":99,"win":true},{"hero_id":114,"win":false},{"hero_id":40,"win":false},{"hero_id":100,"win":false},{"hero_id":34,"win":false},{"hero_id":7,"win":false}]},{"match_id":7036477009,"num_mmr":1,"match_seq_num":5907615804,"duration":1715,"start_time":1677501209,"game_mode":22,"avg_mmr":3326,"avg_rank_tier":44,"players":[{"hero_id":62,"win":false},{"hero_id":67,"win":false},{"hero_id":58,"win":false},{"hero_id":96,"win":false},{"hero_id":31,"win":false},{"hero_id":14,"win":true},{"hero_id":11,"win":true},{"hero_id":63,"win":true},{"hero_id":8,"win":true},{"hero_id":83,"win":true}]},{"match_id":7036477219,"num_mmr":1,"match_seq_num":5907616293,"duration":1732,"start_time":1677501219,"game_mode":22,"avg_mmr":3901,"avg_rank_tier":34,"players":[{"hero_id":75,"win":true},{"hero_id":10,"win":true},{"hero_id":14,"win":true},{"hero_id":94,"win":true},{"hero_id":50,"win":true},{"hero_id":84,"win":false},{"hero_id":120,"win":false},{"hero_id":8,"win":false},{"hero_id":83,"win":false},{"hero_id":76,"win":false}]},{"match_id":7036475207,"num_mmr":null,"match_seq_num":5907617777,"duration":1923,"start_time":1677501133,"game_mode":22,"avg_mmr":null,"avg_rank_tier":23,"players":[{"hero_id":108,"win":false},{"hero_id":41,"win":false},{"hero_id":49,"win":false},{"hero_id":110,"win":false},{"hero_id":42,"win":false},{"hero_id":56,"win":true},{"hero_id":35,"win":true},{"hero_id":121,"win":true},{"hero_id":27,"win":true},{"hero_id":2,"win":true}]},{"match_id":7036480417,"num_mmr":2,"match_seq_num":5907618305,"duration":1692,"start_time":1677501345,"game_mode":22,"avg_mmr":3556,"avg_rank_tier":42,"players":[{"hero_id":56,"win":true},{"hero_id":20,"win":true},{"hero_id":27,"win":true},{"hero_id":43,"win":true},{"hero_id":76,"win":true},{"hero_id":18,"win":false},{"hero_id":96,"win":false},{"hero_id":17,"win":false},{"hero_id":123,"win":false},{"hero_id":33,"win":false}]},{"match_id":7036480214,"num_mmr":2,"match_seq_num":59076204 ...

# %%
d = orjson.loads(x.text)
len(d['rows'][0]['matches'])
# Out:
# 4795

# %%
d['rows'][0]['matches'][0]
# Out:
# {'match_id': 7036473018,
#  'num_mmr': None,
#  'match_seq_num': 5907608475,
#  'duration': 1566,
#  'start_time': 1677501034,
#  'game_mode': 4,
#  'avg_mmr': None,
#  'avg_rank_tier': 44,
#  'players': [{'hero_id': 101, 'win': True},
#   {'hero_id': 71, 'win': True},
#   {'hero_id': 86, 'win': True},
#   {'hero_id': 112, 'win': True},
#   {'hero_id': 136, 'win': True},
#   {'hero_id': 42, 'win': False},
#   {'hero_id': 4, 'win': False},
#   {'hero_id': 22, 'win': False},
#   {'hero_id': 114, 'win': False},
#   {'hero_id': 41, 'win': False}]}

# %%
d['rows'][0]['matches'][5]
# Out:
# {'match_id': 7036477009,
#  'num_mmr': 1,
#  'match_seq_num': 5907615804,
#  'duration': 1715,
#  'start_time': 1677501209,
#  'game_mode': 22,
#  'avg_mmr': 3326,
#  'avg_rank_tier': 44,
#  'players': [{'hero_id': 62, 'win': False},
#   {'hero_id': 67, 'win': False},
#   {'hero_id': 58, 'win': False},
#   {'hero_id': 96, 'win': False},
#   {'hero_id': 31, 'win': False},
#   {'hero_id': 14, 'win': True},
#   {'hero_id': 11, 'win': True},
#   {'hero_id': 63, 'win': True},
#   {'hero_id': 8, 'win': True},
#   {'hero_id': 83, 'win': True}]}

# %%
human = reqreq.replace("%20", " ").replace("%0A", "\n").replace("%2C", ",").replace("%3C", "<").replace("%27", "'").\
    replace("%3D", "=").replace("%3E", ">").replace("%3A", "-")
human
# Out:
# "https://api.opendota.com/api/explorer?sql=SELECT\njson_agg(m) matches\nFROM (\n  SELECT match_id, num_mmr,\n  (\n    SELECT json_agg(p)\n    FROM (\n      SELECT hero_id, ((player_slot < 128) = public_matches.radiant_win) win\n      FROM public_player_matches\n      WHERE true \n      AND match_id = public_matches.match_id \n    ) p\n  ) players\n  FROM public_matches \n  WHERE TRUE \n  AND start_time > extract(epoch from timestamp '2023-02-27T12-29-08.991Z')\n  AND start_time < extract(epoch from timestamp '2023-02-27T13-29-08.991Z')\n  AND duration > 900 \n  \n  AND num_mmr IS NOT NULL\n  LIMIT 5) m"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from picker.scraping.opendota import request_matches
import datetime
import requests
import orjson 
import pandas as pd 
import polars as pl
from time import sleep

# %%
end = datetime.datetime.now() - datetime.timedelta(hours=1)
start = end - datetime.timedelta(days=19)
freq_dt = datetime.timedelta(hours=1)

# %%
df = request_matches(start, end, freq_dt)
# Out:
#   0%|                                                                                                                               | 0/457 [00:00<?, ?it/s]WARNING:root:Statement got timed out, retrying in 5 seconds...
# WARNING:root:Response text: {"err":"error: canceling statement due to statement timeout"}
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 457/457 [46:36<00:00,  6.12s/it]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = request_matches(start, end, freq_dt)
#
# File ~/shad/picker/picker/scraping/opendota.py:116, in request_matches(left_ts, right_ts, freq_dt)
#     113     data.extend(request_matches_by_time(left_ts=start, right_ts=end))
#     115 tmp_df = pd.concat((tmp_df, pd.DataFrame(data)), axis=0)
# --> 116 tmp_df.to_parquet(path=f'DATA/tmp_{left_ts.strftime("%m.%d.%Y.%H.%M.%S")}.parquet')
#     117 return tmp_df
#
# File ~/.cache/pypoetry/virtualenvs/picker-YACZGLA9-py3.10/lib/python3.10/site-packages/pandas/core/frame.py:2889, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2802 """
#    2803 Write a DataFrame to the binary parquet format.
#    2804
#    (...)
#    2885 >>> content = f.read()
#    2886 """
#    2887 from pandas.io.parquet import to_parquet
# -> 2889 return to_parquet(
#    2890     self,
#    2891     path,
#    2892     engine,
#    2893     compression=compression,
#    2894     index=index,
#    2895     partition_cols=partition_cols,
#    2896     storage_options=storage_options,
#    2897     **kwargs,
#    2898 )
#
# File ~/.cache/pypoetry/virtualenvs/picker-YACZGLA9-py3.10/lib/python3.10/site-packages/pandas/io/parquet.py:407, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     405 if isinstance(partition_cols, str):
#     406     partition_cols = [partition_cols]
# --> 407 impl = get_engine(engine)
#     409 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     411 impl.write(
#     412     df,
#     413     path_or_buf,
#    (...)
#     418     **kwargs,
#     419 )
#
# File ~/.cache/pypoetry/virtualenvs/picker-YACZGLA9-py3.10/lib/python3.10/site-packages/pandas/io/parquet.py:60, in get_engine(engine)
#      57         except ImportError as err:
#      58             error_msgs += "\n - " + str(err)
# ---> 60     raise ImportError(
#      61         "Unable to find a usable engine; "
#      62         "tried using: 'pyarrow', 'fastparquet'.\n"
#      63         "A suitable version of "
#      64         "pyarrow or fastparquet is required for parquet "
#      65         "support.\n"
#      66         "Trying to import the above resulted in these errors:"
#      67         f"{error_msgs}"
#      68     )
#      70 if engine == "pyarrow":
#      71     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
# %debug
# Out:
# > /home/yarik/.cache/pypoetry/virtualenvs/picker-YACZGLA9-py3.10/lib/python3.10/site-packages/pandas/io/parquet.py(60)get_engine()
#      58                 error_msgs += "\n - " + str(err)
#      59
# ---> 60         raise ImportError(
#      61             "Unable to find a usable engine; "
#      62             "tried using: 'pyarrow', 'fastparquet'.\n"
#
# ipdb> u
# > /home/yarik/.cache/pypoetry/virtualenvs/picker-YACZGLA9-py3.10/lib/python3.10/site-packages/pandas/io/parquet.py(407)to_parquet()
#     405     if isinstance(partition_cols, str):
#     406         partition_cols = [partition_cols]
# --> 407     impl = get_engine(engine)
#     408
#     409     path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#
# ipdb> u
# > /home/yarik/.cache/pypoetry/virtualenvs/picker-YACZGLA9-py3.10/lib/python3.10/site-packages/pandas/core/frame.py(2889)to_parquet()
#    2887         from pandas.io.parquet import to_parquet
#    2888
# -> 2889         return to_parquet(
#    2890             self,
#    2891             path,
#
# ipdb> u
# > /home/yarik/shad/picker/picker/scraping/opendota.py(116)request_matches()
#     113         data.extend(request_matches_by_time(left_ts=start, right_ts=end))
#     114
#     115     tmp_df = pd.concat((tmp_df, pd.DataFrame(data)), axis=0)
# --> 116     tmp_df.to_parquet(path=f'DATA/tmp_{left_ts.strftime("%m.%d.%Y.%H.%M.%S")}.parquet')
#     117     return tmp_df
#
# ipdb> tmp_df.shape
# (1760216, 11)
# ipdb> %pip install fastparquet
# *** SyntaxError: invalid syntax
# ipdb> tmp_df.to_parquet(path=f'DATA/tmp_{left_ts.strftime("%m.%d.%Y.%H.%M.%S")}.parquet')
# ipdb> tmp_df
#            match_id  match_seq_num  game_mode  start_time  duration
# 0        7122495812     5983460406         22  1682291924      1394  \
# 1        7122494413     5983459057         22  1682291779      1408
# 2        7122497312     5983460085         22  1682292069      1197
# 3        7122494606     5983459115         22  1682291808      1378
# 4        7122496209     5983460222         22  1682291965      1350
# ...             ...            ...        ...         ...       ...
# 1760211  7151785300     6009427050         22  1683936481      4101
# 1760212  7151789008     6009428269         22  1683936882      3644
# 1760213  7151788214     6009430573         22  1683936791      4128
# 1760214  7151788810     6009431133         22  1683936856      4088
# 1760215  7151780916     6009647471         22  1683935996      2045
#
#          avg_rank_tier  avg_mmr  bans             winner_team
# 0                   35   3130.0  None     [67, 79, 86, 59, 2]  \
# 1                   43   2234.0  None     [40, 43, 97, 5, 12]
# 2                   31      NaN  None    [42, 45, 66, 37, 94]
# 3                   61   3502.0  None     [57, 40, 1, 32, 66]
# 4                   33   3417.0  None  [36, 111, 105, 14, 18]
# ...                ...      ...   ...                     ...
# 1760211             43   2398.0  None      [30, 35, 36, 1, 2]
# 1760212             61   4090.0  None    [14, 81, 31, 35, 41]
# 1760213             33   1986.0  None   [113, 101, 5, 99, 70]
# 1760214             52      NaN  None   [102, 35, 37, 27, 97]
# 1760215             61   3985.0  None  [113, 31, 18, 108, 40]
#
#                      loser_team  radiant_won
# 0           [1, 63, 14, 91, 80]        False
# 1         [88, 135, 32, 26, 34]         True
# 2         [27, 104, 75, 35, 47]        False
# 3        [30, 13, 44, 135, 105]        False
# 4          [70, 40, 13, 71, 23]        False
# ...                         ...          ...
# 1760211    [85, 99, 40, 93, 17]        False
# 1760212   [8, 63, 50, 126, 123]        False
# 1760213   [47, 63, 35, 85, 121]        False
# 1760214  [76, 123, 25, 45, 105]         True
# 1760215   [126, 67, 9, 111, 88]        False
#
# [1760216 rows x 11 columns]
# ipdb> tmp_df.shape
# (1760216, 11)
# ipdb> tmp_df.to_csv('kaka.csv')
# ipdb> exit

# %%
df.write_parquet('../DATA/tmp_13.05.23.parquet')

# %%
# start = start - datetime.timedelta(days=7)
# end = end - datetime.timedelta(days=7)
# freq_dt = datetime.timedelta(minutes=15)

# df = request_matches(start, end, freq_dt)

# %%
df.shape
# Out:
# (2433383, 11)

# %%
df[((df['game_mode'] == 22) | (df['game_mode'] <= 4)) & (df['avg_rank_tier'] >= 30)]
# Out:
#            match_id  match_seq_num  game_mode  start_time  duration  \
# 0        7069218302     5936308834         22  1679306960      1687
# 1        7069219414     5936310645         22  1679307020      1750
# 2        7069218516     5936310704         22  1679306975      1801
# 4        7069226911     5936311208         22  1679307481      1313
# 5        7069218103     5936311433         22  1679306949      1886
# ...             ...            ...        ...         ...       ...
# 1199133  7090359417     5955028180         22  1680518214      3594
# 1199135  7090360611     5955032298         22  1680518274      3811
# 1199140  7090349805     5955042658         22  1680517612      5145
# 1199142  7090357311     5955043342         22  1680518082      4455
# 1199143  7090361209     5955464388         22  1680518314      2816
#
#          avg_rank_tier  avg_mmr  bans             winner_team  \
# 0                   54   3713.0  None   [73, 135, 75, 31, 44]
# 1                   33   3273.0  None    [1, 26, 102, 40, 16]
# 2                   71   5102.0  None    [87, 23, 29, 70, 32]
# 4                   72   3723.0  None   [93, 64, 14, 112, 74]
# 5                   33   2782.0  None   [128, 56, 1, 101, 97]
# ...                ...      ...   ...                     ...
# 1199133             65   3637.0  None   [12, 123, 47, 106, 7]
# 1199135             42   2741.0  None   [74, 3, 138, 104, 82]
# 1199140             41   2557.0  None   [21, 136, 74, 1, 105]
# 1199142             55   3208.0  None  [96, 86, 42, 105, 113]
# 1199143             41   2617.0  None    [11, 19, 93, 75, 10]
#
#                      loser_team
# 0         [42, 71, 9, 104, 121]
# 1          [104, 9, 67, 50, 22]
# 2          [14, 138, 26, 5, 44]
# 4        [84, 106, 6, 101, 138]
# 5           [5, 33, 72, 41, 71]
# ...                         ...
# 1199133   [98, 10, 40, 138, 71]
# 1199135    [31, 7, 27, 123, 44]
# 1199140   [84, 56, 39, 50, 129]
# 1199142   [41, 137, 101, 35, 7]
# 1199143     [36, 5, 39, 104, 8]
#
# [763416 rows x 10 columns]

# %%
df[df['game_mode'] == 22].shape
# Out:
# (1100938, 10)

# %%
df.describe()
# Out:
#            match_id  match_seq_num     game_mode    start_time      duration  \
# count  1.199144e+06   1.199144e+06  1.199144e+06  1.199144e+06  1.199144e+06
# mean   7.079851e+09   5.945684e+09  2.048571e+01  1.679916e+09  2.511092e+03
# std    6.139385e+06   5.405803e+06  5.073492e+00  3.507146e+05  5.895160e+02
# min    7.069218e+09   5.936307e+09  1.000000e+00  1.679307e+09  9.010000e+02
# 25%    7.074494e+09   5.940965e+09  2.200000e+01  1.679614e+09  2.095000e+03
# 50%    7.079812e+09   5.945665e+09  2.200000e+01  1.679910e+09  2.469000e+03
# 75%    7.085195e+09   5.950345e+09  2.200000e+01  1.680230e+09  2.852000e+03
# max    7.090362e+09   5.955464e+09  2.200000e+01  1.680518e+09  9.065000e+03
#
#        avg_rank_tier        avg_mmr
# count   1.199144e+06  790752.000000
# mean    3.526046e+01    2966.475014
# std     1.565150e+01     968.526621
# min     1.100000e+01       1.000000
# 25%     2.300000e+01    2364.000000
# 50%     3.300000e+01    3033.000000
# 75%     4.400000e+01    3612.000000
# max     8.100000e+01    8728.000000

# %%
df['game_mode'] <= 4
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1199139    False
# 1199140    False
# 1199141    False
# 1199142    False
# 1199143    False
# Name: game_mode, Length: 1199144, dtype: bool

# %%
raw = requests.get('http://api.steampowered.com/IDOTA2Match_570/GetMatchHistoryBySequenceNum/v1',
                   params={'start_at_match_seq_num': 5942261634,
                           'key': 'A6333E0CC31A3C6E18278FDB8F2AC983'})
print(raw.text)
# Out:
# {
# "result":{
# "status":1,
# "matches":[
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":18,
# "item_0":63,
# "item_1":73,
# "item_2":73,
# "item_3":46,
# "item_4":16,
# "item_5":8,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":3,
# "deaths":15,
# "assists":5,
# "leaver_status":0,
# "last_hits":41,
# "denies":0,
# "gold_per_min":172,
# "xp_per_min":260,
# "level":14,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":54008249,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":31,
# "item_0":1,
# "item_1":60,
# "item_2":21,
# "item_3":46,
# "item_4":29,
# "item_5":22,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":6,
# "deaths":9,
# "assists":6,
# "leaver_status":0,
# "last_hits":48,
# "denies":14,
# "gold_per_min":195,
# "xp_per_min":306,
# "level":15,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":4,
# "item_0":170,
# "item_1":11,
# "item_2":75,
# "item_3":29,
# "item_4":149,
# "item_5":21,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":16,
# "assists":8,
# "leaver_status":0,
# "last_hits":73,
# "denies":0,
# "gold_per_min":207,
# "xp_per_min":289,
# "level":14,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":25,
# "item_0":50,
# "item_1":20,
# "item_2":20,
# "item_3":60,
# "item_4":13,
# "item_5":23,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":12,
# "assists":9,
# "leaver_status":0,
# "last_hits":34,
# "denies":6,
# "gold_per_min":174,
# "xp_per_min":216,
# "level":12,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":47,
# "item_0":125,
# "item_1":60,
# "item_2":20,
# "item_3":13,
# "item_4":63,
# "item_5":21,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":10,
# "deaths":12,
# "assists":1,
# "leaver_status":0,
# "last_hits":62,
# "denies":1,
# "gold_per_min":226,
# "xp_per_min":298,
# "level":15,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":19,
# "item_0":41,
# "item_1":1,
# "item_2":48,
# "item_3":125,
# "item_4":131,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":21,
# "deaths":6,
# "assists":17,
# "leaver_status":0,
# "last_hits":53,
# "denies":0,
# "gold_per_min":367,
# "xp_per_min":663,
# "level":22,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":14,
# "item_0":73,
# "item_1":131,
# "item_2":63,
# "item_3":114,
# "item_4":4,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":11,
# "deaths":5,
# "assists":11,
# "leaver_status":0,
# "last_hits":34,
# "denies":1,
# "gold_per_min":314,
# "xp_per_min":545,
# "level":20,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":33,
# "item_0":1,
# "item_1":116,
# "item_2":41,
# "item_3":29,
# "item_4":88,
# "item_5":137,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":13,
# "deaths":6,
# "assists":16,
# "leaver_status":0,
# "last_hits":135,
# "denies":7,
# "gold_per_min":425,
# "xp_per_min":577,
# "level":21,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":13,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":115,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":15,
# "item_0":36,
# "item_1":63,
# "item_2":156,
# "item_3":75,
# "item_4":125,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":14,
# "deaths":7,
# "assists":28,
# "leaver_status":0,
# "last_hits":98,
# "denies":0,
# "gold_per_min":396,
# "xp_per_min":672,
# "level":22,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":2408,
# "pre_game_duration":0,
# "start_time":1299121489,
# "match_id":496,
# "match_seq_num":240,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":42744364,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":20,
# "item_0":48,
# "item_1":48,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":5,
# "denies":0,
# "gold_per_min":51,
# "xp_per_min":6,
# "level":4,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":9900,
# "pre_game_duration":0,
# "start_time":1299123864,
# "match_id":497,
# "match_seq_num":241,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":1,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":4,
# "item_0":102,
# "item_1":36,
# "item_2":75,
# "item_3":11,
# "item_4":63,
# "item_5":61,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":5,
# "deaths":1,
# "assists":3,
# "leaver_status":1,
# "last_hits":80,
# "denies":24,
# "gold_per_min":299,
# "xp_per_min":395,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":18,
# "item_0":63,
# "item_1":21,
# "item_2":46,
# "item_3":73,
# "item_4":16,
# "item_5":73,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":2,
# "assists":2,
# "leaver_status":1,
# "last_hits":29,
# "denies":2,
# "gold_per_min":187,
# "xp_per_min":232,
# "level":10,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":21,
# "item_0":178,
# "item_1":73,
# "item_2":63,
# "item_3":77,
# "item_4":24,
# "item_5":88,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":4,
# "deaths":1,
# "assists":6,
# "leaver_status":1,
# "last_hits":47,
# "denies":3,
# "gold_per_min":257,
# "xp_per_min":296,
# "level":11,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":49657570,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":2,
# "item_0":50,
# "item_1":16,
# "item_2":16,
# "item_3":125,
# "item_4":60,
# "item_5":16,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":13,
# "deaths":3,
# "assists":5,
# "leaver_status":1,
# "last_hits":43,
# "denies":0,
# "gold_per_min":331,
# "xp_per_min":555,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":8,
# "item_0":63,
# "item_1":26,
# "item_2":36,
# "item_3":73,
# "item_4":34,
# "item_5":11,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":3,
# "deaths":0,
# "assists":1,
# "leaver_status":0,
# "last_hits":39,
# "denies":0,
# "gold_per_min":223,
# "xp_per_min":314,
# "level":12,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":899337,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":25,
# "item_0":44,
# "item_1":0,
# "item_2":38,
# "item_3":42,
# "item_4":17,
# "item_5":46,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":6,
# "assists":1,
# "leaver_status":1,
# "last_hits":19,
# "denies":5,
# "gold_per_min":111,
# "xp_per_min":141,
# "level":8,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":54008249,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":41,
# "item_0":63,
# "item_1":11,
# "item_2":71,
# "item_3":172,
# "item_4":46,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":3,
# "deaths":4,
# "assists":1,
# "leaver_status":1,
# "last_hits":77,
# "denies":4,
# "gold_per_min":247,
# "xp_per_min":406,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":16,
# "item_0":73,
# "item_1":73,
# "item_2":46,
# "item_3":0,
# "item_4":29,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":2,
# "assists":0,
# "leaver_status":1,
# "last_hits":25,
# "denies":0,
# "gold_per_min":134,
# "xp_per_min":182,
# "level":9,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":31,
# "item_0":34,
# "item_1":29,
# "item_2":73,
# "item_3":73,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":8,
# "assists":2,
# "leaver_status":1,
# "last_hits":11,
# "denies":3,
# "gold_per_min":106,
# "xp_per_min":112,
# "level":7,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":68234275,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":47,
# "item_0":73,
# "item_1":20,
# "item_2":44,
# "item_3":25,
# "item_4":29,
# "item_5":41,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":7,
# "assists":2,
# "leaver_status":1,
# "last_hits":26,
# "denies":0,
# "gold_per_min":151,
# "xp_per_min":245,
# "level":10,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":true,
# "duration":1514,
# "pre_game_duration":0,
# "start_time":1299136413,
# "match_id":499,
# "match_seq_num":243,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":1370127,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":26,
# "item_0":41,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":67,
# "xp_per_min":18,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":2,
# "item_0":63,
# "item_1":16,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":0,
# "assists":0,
# "leaver_status":0,
# "last_hits":9,
# "denies":0,
# "gold_per_min":219,
# "xp_per_min":295,
# "level":5,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":14,
# "item_0":13,
# "item_1":13,
# "item_2":39,
# "item_3":38,
# "item_4":16,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":67,
# "xp_per_min":82,
# "level":3,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":54008249,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":10,
# "item_0":12,
# "item_1":14,
# "item_2":44,
# "item_3":39,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":3,
# "denies":1,
# "gold_per_min":89,
# "xp_per_min":97,
# "level":3,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":25,
# "item_0":44,
# "item_1":38,
# "item_2":39,
# "item_3":13,
# "item_4":13,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":1,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":67,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":15,
# "item_0":29,
# "item_1":0,
# "item_2":41,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":1,
# "assists":0,
# "leaver_status":1,
# "last_hits":9,
# "denies":1,
# "gold_per_min":129,
# "xp_per_min":296,
# "level":5,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":41,
# "item_0":11,
# "item_1":44,
# "item_2":182,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":67,
# "xp_per_min":37,
# "level":2,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# }
# ]
# ,
# "radiant_win":true,
# "duration":392,
# "pre_game_duration":0,
# "start_time":1299138675,
# "match_id":501,
# "match_seq_num":246,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":7,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":14,
# "item_0":13,
# "item_1":13,
# "item_2":39,
# "item_3":38,
# "item_4":16,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":0,
# "last_hits":3,
# "denies":0,
# "gold_per_min":135,
# "xp_per_min":217,
# "level":2,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":7,
# "item_0":38,
# "item_1":44,
# "item_2":13,
# "item_3":16,
# "item_4":16,
# "item_5":16,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":1,
# "denies":0,
# "gold_per_min":88,
# "xp_per_min":132,
# "level":2,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":20,
# "item_0":44,
# "item_1":29,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":1,
# "denies":0,
# "gold_per_min":91,
# "xp_per_min":58,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":25,
# "item_0":44,
# "item_1":38,
# "item_2":39,
# "item_3":13,
# "item_4":13,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":1,
# "denies":1,
# "gold_per_min":88,
# "xp_per_min":127,
# "level":2,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":4,
# "item_0":11,
# "item_1":44,
# "item_2":14,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":1,
# "denies":0,
# "gold_per_min":94,
# "xp_per_min":58,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":8,
# "item_0":44,
# "item_1":11,
# "item_2":16,
# "item_3":16,
# "item_4":38,
# "item_5":39,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":68,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":22,
# "item_0":44,
# "item_1":38,
# "item_2":39,
# "item_3":13,
# "item_4":13,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":68,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":47,
# "item_0":38,
# "item_1":39,
# "item_2":44,
# "item_3":16,
# "item_4":16,
# "item_5":16,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":68,
# "xp_per_min":73,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":18,
# "item_0":39,
# "item_1":38,
# "item_2":13,
# "item_3":20,
# "item_4":44,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":68,
# "xp_per_min":233,
# "level":2,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# }
# ]
# ,
# "radiant_win":true,
# "duration":116,
# "pre_game_duration":0,
# "start_time":1299265964,
# "match_id":504,
# "match_seq_num":248,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":9,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":32,
# "item_0":11,
# "item_1":63,
# "item_2":174,
# "item_3":71,
# "item_4":46,
# "item_5":10,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":4,
# "deaths":5,
# "assists":3,
# "leaver_status":0,
# "last_hits":67,
# "denies":0,
# "gold_per_min":191,
# "xp_per_min":351,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":68234275,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":28,
# "item_0":73,
# "item_1":63,
# "item_2":73,
# "item_3":164,
# "item_4":20,
# "item_5":2,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":6,
# "assists":2,
# "leaver_status":1,
# "last_hits":48,
# "denies":4,
# "gold_per_min":155,
# "xp_per_min":211,
# "level":12,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":8,
# "item_0":39,
# "item_1":44,
# "item_2":22,
# "item_3":36,
# "item_4":56,
# "item_5":63,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":11,
# "assists":0,
# "leaver_status":0,
# "last_hits":78,
# "denies":0,
# "gold_per_min":193,
# "xp_per_min":230,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":41,
# "item_0":71,
# "item_1":2,
# "item_2":73,
# "item_3":63,
# "item_4":60,
# "item_5":7,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":5,
# "deaths":5,
# "assists":1,
# "leaver_status":0,
# "last_hits":51,
# "denies":0,
# "gold_per_min":210,
# "xp_per_min":302,
# "level":15,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":6,
# "item_0":63,
# "item_1":75,
# "item_2":16,
# "item_3":22,
# "item_4":17,
# "item_5":39,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":14,
# "assists":3,
# "leaver_status":0,
# "last_hits":60,
# "denies":0,
# "gold_per_min":185,
# "xp_per_min":235,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":20,
# "item_0":41,
# "item_1":63,
# "item_2":114,
# "item_3":26,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":0,
# "assists":15,
# "leaver_status":0,
# "last_hits":81,
# "denies":0,
# "gold_per_min":270,
# "xp_per_min":470,
# "level":18,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":31,
# "item_0":36,
# "item_1":50,
# "item_2":0,
# "item_3":79,
# "item_4":73,
# "item_5":73,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":4,
# "assists":10,
# "leaver_status":0,
# "last_hits":41,
# "denies":6,
# "gold_per_min":236,
# "xp_per_min":367,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":47,
# "item_0":63,
# "item_1":56,
# "item_2":104,
# "item_3":46,
# "item_4":168,
# "item_5":117,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":10,
# "deaths":3,
# "assists":3,
# "leaver_status":0,
# "last_hits":120,
# "denies":2,
# "gold_per_min":344,
# "xp_per_min":372,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":15,
# "item_0":29,
# "item_1":54,
# "item_2":41,
# "item_3":170,
# "item_4":0,
# "item_5":125,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":9,
# "deaths":3,
# "assists":12,
# "leaver_status":0,
# "last_hits":100,
# "denies":2,
# "gold_per_min":322,
# "xp_per_min":458,
# "level":18,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":22,
# "item_0":41,
# "item_1":29,
# "item_2":77,
# "item_3":108,
# "item_4":129,
# "item_5":88,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":13,
# "deaths":3,
# "assists":11,
# "leaver_status":0,
# "last_hits":96,
# "denies":0,
# "gold_per_min":322,
# "xp_per_min":561,
# "level":20,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":2370,
# "pre_game_duration":0,
# "start_time":1299266253,
# "match_id":505,
# "match_seq_num":249,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":7,
# "item_0":73,
# "item_1":180,
# "item_2":1,
# "item_3":73,
# "item_4":16,
# "item_5":162,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":17,
# "assists":10,
# "leaver_status":0,
# "last_hits":90,
# "denies":7,
# "gold_per_min":244,
# "xp_per_min":453,
# "level":19,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":72557050,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":2,
# "item_0":63,
# "item_1":125,
# "item_2":44,
# "item_3":39,
# "item_4":26,
# "item_5":16,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":6,
# "deaths":17,
# "assists":6,
# "leaver_status":0,
# "last_hits":34,
# "denies":0,
# "gold_per_min":193,
# "xp_per_min":327,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":8,
# "item_0":11,
# "item_1":164,
# "item_2":5,
# "item_3":63,
# "item_4":0,
# "item_5":3,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":5,
# "deaths":13,
# "assists":6,
# "leaver_status":0,
# "last_hits":64,
# "denies":0,
# "gold_per_min":219,
# "xp_per_min":418,
# "level":18,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":29,
# "item_0":73,
# "item_1":63,
# "item_2":0,
# "item_3":36,
# "item_4":0,
# "item_5":46,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":18,
# "assists":10,
# "leaver_status":0,
# "last_hits":35,
# "denies":0,
# "gold_per_min":154,
# "xp_per_min":229,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":14,
# "item_0":92,
# "item_1":131,
# "item_2":29,
# "item_3":21,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":5,
# "deaths":14,
# "assists":6,
# "leaver_status":0,
# "last_hits":49,
# "denies":4,
# "gold_per_min":184,
# "xp_per_min":282,
# "level":15,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":22,
# "item_0":36,
# "item_1":41,
# "item_2":108,
# "item_3":29,
# "item_4":46,
# "item_5":73,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":6,
# "deaths":4,
# "assists":40,
# "leaver_status":0,
# "last_hits":34,
# "denies":0,
# "gold_per_min":261,
# "xp_per_min":480,
# "level":20,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":19,
# "item_0":73,
# "item_1":180,
# "item_2":108,
# "item_3":114,
# "item_4":172,
# "item_5":21,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":21,
# "deaths":4,
# "assists":39,
# "leaver_status":0,
# "last_hits":90,
# "denies":1,
# "gold_per_min":437,
# "xp_per_min":748,
# "level":25,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":18,
# "item_0":41,
# "item_1":63,
# "item_2":73,
# "item_3":0,
# "item_4":116,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":8,
# "assists":29,
# "leaver_status":0,
# "last_hits":53,
# "denies":0,
# "gold_per_min":264,
# "xp_per_min":385,
# "level":17,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":32,
# "item_0":11,
# "item_1":63,
# "item_2":174,
# "item_3":112,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":13,
# "deaths":8,
# "assists":12,
# "leaver_status":0,
# "last_hits":57,
# "denies":0,
# "gold_per_min":314,
# "xp_per_min":535,
# "level":21,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":47,
# "item_0":63,
# "item_1":125,
# "item_2":114,
# "item_3":108,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":29,
# "deaths":4,
# "assists":26,
# "leaver_status":0,
# "last_hits":63,
# "denies":0,
# "gold_per_min":415,
# "xp_per_min":657,
# "level":23,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":2619,
# "pre_game_duration":0,
# "start_time":1299266365,
# "match_id":506,
# "match_seq_num":250,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":15,
# "item_0":41,
# "item_1":36,
# "item_2":178,
# "item_3":125,
# "item_4":63,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":3,
# "deaths":7,
# "assists":8,
# "leaver_status":0,
# "last_hits":52,
# "denies":0,
# "gold_per_min":181,
# "xp_per_min":281,
# "level":15,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":29,
# "item_0":34,
# "item_1":73,
# "item_2":46,
# "item_3":63,
# "item_4":42,
# "item_5":13,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":1,
# "deaths":16,
# "assists":8,
# "leaver_status":0,
# "last_hits":41,
# "denies":1,
# "gold_per_min":145,
# "xp_per_min":224,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":14,
# "item_0":63,
# "item_1":13,
# "item_2":131,
# "item_3":13,
# "item_4":61,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":9,
# "assists":5,
# "leaver_status":0,
# "last_hits":60,
# "denies":0,
# "gold_per_min":211,
# "xp_per_min":336,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":31,
# "item_0":131,
# "item_1":77,
# "item_2":63,
# "item_3":46,
# "item_4":56,
# "item_5":69,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":9,
# "deaths":6,
# "assists":8,
# "leaver_status":0,
# "last_hits":81,
# "denies":17,
# "gold_per_min":240,
# "xp_per_min":435,
# "level":18,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":19,
# "item_0":77,
# "item_1":63,
# "item_2":36,
# "item_3":0,
# "item_4":0,
# "item_5":44,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":9,
# "assists":8,
# "leaver_status":0,
# "last_hits":17,
# "denies":0,
# "gold_per_min":141,
# "xp_per_min":172,
# "level":11,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":28,
# "item_0":73,
# "item_1":112,
# "item_2":151,
# "item_3":63,
# "item_4":73,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":19,
# "deaths":8,
# "assists":10,
# "leaver_status":0,
# "last_hits":69,
# "denies":1,
# "gold_per_min":337,
# "xp_per_min":529,
# "level":20,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":4,
# "item_0":75,
# "item_1":133,
# "item_2":11,
# "item_3":29,
# "item_4":172,
# "item_5":55,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":5,
# "assists":12,
# "leaver_status":0,
# "last_hits":128,
# "denies":0,
# "gold_per_min":338,
# "xp_per_min":602,
# "level":22,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":2,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":114,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":30,
# "item_0":92,
# "item_1":34,
# "item_2":96,
# "item_3":46,
# "item_4":56,
# "item_5":63,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":13,
# "deaths":3,
# "assists":14,
# "leaver_status":0,
# "last_hits":53,
# "denies":9,
# "gold_per_min":303,
# "xp_per_min":513,
# "level":20,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":24181910,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":33,
# "item_0":88,
# "item_1":121,
# "item_2":180,
# "item_3":50,
# "item_4":42,
# "item_5":1,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":5,
# "assists":17,
# "leaver_status":0,
# "last_hits":117,
# "denies":1,
# "gold_per_min":312,
# "xp_per_min":362,
# "level":17,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":2554,
# "pre_game_duration":0,
# "start_time":1299267772,
# "match_id":507,
# "match_seq_num":251,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":1370127,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":7,
# "item_0":41,
# "item_1":1,
# "item_2":50,
# "item_3":125,
# "item_4":36,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":6,
# "deaths":3,
# "assists":16,
# "leaver_status":0,
# "last_hits":27,
# "denies":1,
# "gold_per_min":261,
# "xp_per_min":424,
# "level":18,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":19,
# "item_0":180,
# "item_1":73,
# "item_2":110,
# "item_3":114,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":23,
# "deaths":5,
# "assists":12,
# "leaver_status":0,
# "last_hits":103,
# "denies":1,
# "gold_per_min":408,
# "xp_per_min":694,
# "level":23,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":25,
# "item_0":121,
# "item_1":108,
# "item_2":0,
# "item_3":63,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":11,
# "deaths":5,
# "assists":23,
# "leaver_status":0,
# "last_hits":74,
# "denies":1,
# "gold_per_min":333,
# "xp_per_min":578,
# "level":21,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":22,
# "item_0":180,
# "item_1":110,
# "item_2":0,
# "item_3":41,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":4,
# "deaths":6,
# "assists":18,
# "leaver_status":0,
# "last_hits":65,
# "denies":0,
# "gold_per_min":220,
# "xp_per_min":258,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":6,
# "item_0":63,
# "item_1":139,
# "item_2":22,
# "item_3":18,
# "item_4":39,
# "item_5":38,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":8,
# "deaths":6,
# "assists":10,
# "leaver_status":0,
# "last_hits":95,
# "denies":0,
# "gold_per_min":336,
# "xp_per_min":492,
# "level":19,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":2,
# "item_0":63,
# "item_1":125,
# "item_2":73,
# "item_3":73,
# "item_4":44,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":12,
# "assists":1,
# "leaver_status":0,
# "last_hits":65,
# "denies":0,
# "gold_per_min":176,
# "xp_per_min":330,
# "level":15,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":31,
# "item_0":36,
# "item_1":50,
# "item_2":73,
# "item_3":79,
# "item_4":42,
# "item_5":73,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":8,
# "deaths":17,
# "assists":9,
# "leaver_status":0,
# "last_hits":33,
# "denies":3,
# "gold_per_min":173,
# "xp_per_min":255,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":8,
# "item_0":11,
# "item_1":164,
# "item_2":63,
# "item_3":69,
# "item_4":0,
# "item_5":16,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":8,
# "deaths":12,
# "assists":7,
# "leaver_status":0,
# "last_hits":68,
# "denies":0,
# "gold_per_min":219,
# "xp_per_min":460,
# "level":18,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":16,
# "item_0":13,
# "item_1":63,
# "item_2":21,
# "item_3":127,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":10,
# "assists":7,
# "leaver_status":0,
# "last_hits":43,
# "denies":0,
# "gold_per_min":186,
# "xp_per_min":366,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":21,
# "item_0":44,
# "item_1":77,
# "item_2":38,
# "item_3":77,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":5,
# "assists":0,
# "leaver_status":1,
# "last_hits":14,
# "denies":2,
# "gold_per_min":101,
# "xp_per_min":47,
# "level":5,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":true,
# "duration":2407,
# "pre_game_duration":0,
# "start_time":1299270133,
# "match_id":508,
# "match_seq_num":252,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":42744364,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":50,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":15,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":8,
# "item_0":29,
# "item_1":39,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":21,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":22,
# "item_0":44,
# "item_1":38,
# "item_2":39,
# "item_3":13,
# "item_4":13,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":31,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":2,
# "item_0":182,
# "item_1":39,
# "item_2":44,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":899337,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":7,
# "item_0":38,
# "item_1":44,
# "item_2":39,
# "item_3":13,
# "item_4":16,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":60332681,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":9,
# "item_0":14,
# "item_1":14,
# "item_2":44,
# "item_3":39,
# "item_4":38,
# "item_5":20,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# ...
# "last_hits":25,
# "denies":1,
# "gold_per_min":204,
# "xp_per_min":274,
# "level":7,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":26,
# "item_0":34,
# "item_1":29,
# "item_2":16,
# "item_3":60,
# "item_4":16,
# "item_5":16,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":5,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":9,
# "denies":4,
# "gold_per_min":225,
# "xp_per_min":339,
# "level":8,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":true,
# "duration":647,
# "pre_game_duration":0,
# "start_time":1302325101,
# "match_id":648,
# "match_seq_num":392,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":28,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":5,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":1370127,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":36,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":40,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":7,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":32,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":50,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":42,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "leaver_status":1,
# "last_hits":0,
# "denies":0,
# "gold_per_min":3600,
# "xp_per_min":0,
# "level":1,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":0,
# "pre_game_duration":0,
# "start_time":1302327179,
# "match_id":651,
# "match_seq_num":395,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":8,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "account_id":4294967295,
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":17,
# "item_0":41,
# "item_1":36,
# "item_2":77,
# "item_3":63,
# "item_4":46,
# "item_5":77,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":4,
# "deaths":1,
# "assists":15,
# "leaver_status":0,
# "last_hits":72,
# "denies":5,
# "gold_per_min":335,
# "xp_per_min":377,
# "level":13,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":42744364,
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":14,
# "item_0":92,
# "item_1":36,
# "item_2":108,
# "item_3":0,
# "item_4":178,
# "item_5":29,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":16,
# "deaths":3,
# "assists":15,
# "leaver_status":0,
# "last_hits":36,
# "denies":0,
# "gold_per_min":372,
# "xp_per_min":610,
# "level":16,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":50,
# "item_0":180,
# "item_1":92,
# "item_2":79,
# "item_3":0,
# "item_4":0,
# "item_5":88,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":7,
# "deaths":1,
# "assists":24,
# "leaver_status":0,
# "last_hits":37,
# "denies":5,
# "gold_per_min":335,
# "xp_per_min":473,
# "level":14,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":26,
# "item_0":36,
# "item_1":121,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":29,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":13,
# "deaths":2,
# "assists":20,
# "leaver_status":0,
# "last_hits":21,
# "denies":4,
# "gold_per_min":325,
# "xp_per_min":477,
# "level":14,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":42,
# "item_0":92,
# "item_1":50,
# "item_2":36,
# "item_3":54,
# "item_4":6,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":9,
# "deaths":1,
# "assists":15,
# "leaver_status":0,
# "last_hits":62,
# "denies":6,
# "gold_per_min":409,
# "xp_per_min":479,
# "level":14,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":899337,
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":18,
# "item_0":73,
# "item_1":0,
# "item_2":73,
# "item_3":29,
# "item_4":36,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":10,
# "assists":2,
# "leaver_status":0,
# "last_hits":22,
# "denies":5,
# "gold_per_min":151,
# "xp_per_min":179,
# "level":9,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":2,
# "item_0":182,
# "item_1":56,
# "item_2":44,
# "item_3":16,
# "item_4":0,
# "item_5":29,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":12,
# "assists":2,
# "leaver_status":0,
# "last_hits":19,
# "denies":0,
# "gold_per_min":125,
# "xp_per_min":133,
# "level":7,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":4294967295,
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":40,
# "item_0":44,
# "item_1":38,
# "item_2":63,
# "item_3":56,
# "item_4":182,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":10,
# "assists":2,
# "leaver_status":0,
# "last_hits":27,
# "denies":0,
# "gold_per_min":149,
# "xp_per_min":190,
# "level":9,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":68234275,
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":47,
# "item_0":63,
# "item_1":13,
# "item_2":13,
# "item_3":16,
# "item_4":0,
# "item_5":39,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":3,
# "deaths":10,
# "assists":0,
# "leaver_status":0,
# "last_hits":25,
# "denies":4,
# "gold_per_min":163,
# "xp_per_min":213,
# "level":9,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# },
# {
# "account_id":45100880,
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":5,
# "item_0":73,
# "item_1":50,
# "item_2":73,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":2,
# "deaths":7,
# "assists":2,
# "leaver_status":0,
# "last_hits":23,
# "denies":2,
# "gold_per_min":159,
# "xp_per_min":200,
# "level":9,
# "net_worth":0,
# "aghanims_scepter":0,
# "aghanims_shard":0,
# "moonshard":0
# }
# ]
# ,
# "radiant_win":true,
# "duration":1468,
# "pre_game_duration":0,
# "start_time":1302326111,
# "match_id":653,
# "match_seq_num":397,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":10,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# },
# {
# "players":[
# {
# "player_slot":0,
# "team_number":0,
# "team_slot":0,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":1,
# "team_number":0,
# "team_slot":1,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":2,
# "team_number":0,
# "team_slot":2,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":3,
# "team_number":0,
# "team_slot":3,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":4,
# "team_number":0,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":128,
# "team_number":1,
# "team_slot":0,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":129,
# "team_number":1,
# "team_slot":1,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":130,
# "team_number":1,
# "team_slot":2,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":131,
# "team_number":1,
# "team_slot":3,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# },
# {
# "player_slot":132,
# "team_number":1,
# "team_slot":4,
# "hero_id":0,
# "item_0":0,
# "item_1":0,
# "item_2":0,
# "item_3":0,
# "item_4":0,
# "item_5":0,
# "backpack_0":0,
# "backpack_1":0,
# "backpack_2":0,
# "item_neutral":0,
# "kills":0,
# "deaths":0,
# "assists":0,
# "hero_damage":0,
# "tower_damage":0,
# "hero_healing":0,
# "gold":0,
# "last_hits":0,
# "denies":0,
# "gold_per_min":0,
# "xp_per_min":0,
# "gold_spent":0,
# "scaled_hero_damage":0,
# "scaled_tower_damage":0,
# "scaled_hero_healing":0,
# "level":0,
# "net_worth":0
# }
# ]
# ,
# "radiant_win":false,
# "duration":0,
# "pre_game_duration":0,
# "start_time":1302327641,
# "match_id":654,
# "match_seq_num":398,
# "tower_status_radiant":0,
# "tower_status_dire":0,
# "barracks_status_radiant":0,
# "barracks_status_dire":0,
# "cluster":0,
# "first_blood_time":0,
# "lobby_type":0,
# "human_players":0,
# "leagueid":0,
# "positive_votes":0,
# "negative_votes":0,
# "game_mode":0,
# "flags":0,
# "engine":0,
# "radiant_score":0,
# "dire_score":0
# }
# ]
#
# }
# }

# %%
import pickle
import requests
import orjson 
import pandas as pd 
import polars as pl
from time import sleep

# %%
with open('dump', 'rb') as f:
    raw_text = pickle.load(f)

# %%
qwe = orjson.loads(raw_text)

# %%
match0 = qwe['result']['matches'][0]

# %%
match0.keys()
# Out:
# dict_keys(['players', 'radiant_win', 'duration', 'pre_game_duration', 'start_time', 'match_id', 'match_seq_num', 'tower_status_radiant', 'tower_status_dire', 'barracks_status_radiant', 'barracks_status_dire', 'cluster', 'first_blood_time', 'lobby_type', 'human_players', 'leagueid', 'positive_votes', 'negative_votes', 'game_mode', 'flags', 'engine', 'radiant_score', 'dire_score'])

# %%
len(qwe['result'])
# Out:
# 2

# %%
from copy import deepcopy
match_c = deepcopy(qwe['result']['matches'][0])
match_c['players'] = None
match_c
# Out:
# {'players': None,
#  'radiant_win': False,
#  'duration': 2408,
#  'pre_game_duration': 0,
#  'start_time': 1299121489,
#  'match_id': 496,
#  'match_seq_num': 240,
#  'tower_status_radiant': 0,
#  'tower_status_dire': 0,
#  'barracks_status_radiant': 0,
#  'barracks_status_dire': 0,
#  'cluster': 0,
#  'first_blood_time': 0,
#  'lobby_type': 0,
#  'human_players': 10,
#  'leagueid': 0,
#  'positive_votes': 0,
#  'negative_votes': 0,
#  'game_mode': 0,
#  'flags': 0,
#  'engine': 0,
#  'radiant_score': 0,
#  'dire_score': 0}

# %%
match0['match_id']
# Out:
# 496

# %%
match0['match_seq_num']
# Out:
# 240

# %%
match0['players'][0]
# Out:
# {'account_id': 4294967295,
#  'player_slot': 0,
#  'team_number': 0,
#  'team_slot': 0,
#  'hero_id': 18,
#  'item_0': 63,
#  'item_1': 73,
#  'item_2': 73,
#  'item_3': 46,
#  'item_4': 16,
#  'item_5': 8,
#  'backpack_0': 0,
#  'backpack_1': 0,
#  'backpack_2': 0,
#  'item_neutral': 0,
#  'kills': 3,
#  'deaths': 15,
#  'assists': 5,
#  'leaver_status': 0,
#  'last_hits': 41,
#  'denies': 0,
#  'gold_per_min': 172,
#  'xp_per_min': 260,
#  'level': 14,
#  'net_worth': 0,
#  'aghanims_scepter': 0,
#  'aghanims_shard': 0,
#  'moonshard': 0}

# %%
18000000 / 1000 / 60
# Out:
# 300.0

# %%
qwe['result']['matches'][0].keys()
# Out:
# dict_keys(['players', 'radiant_win', 'duration', 'pre_game_duration', 'start_time', 'match_id', 'match_seq_num', 'tower_status_radiant', 'tower_status_dire', 'barracks_status_radiant', 'barracks_status_dire', 'cluster', 'first_blood_time', 'lobby_type', 'human_players', 'leagueid', 'positive_votes', 'negative_votes', 'game_mode', 'flags', 'engine', 'radiant_score', 'dire_score', 'picks_bans'])

# %%
qwe['result']['matches'][0]['match_seq_num']
# Out:
# 5942261634

# %%
qwe['result']['matches'][1]['match_seq_num']
# Out:
# 241

# %%
(5946248560 - 5909520709) // 2 + 5909520709
# Out:
# 5927884634

# %%
(5946248560 - 5909520709) // 2
# Out:
# 18363925

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import polars as pl

# %%
df = pl.read_parquet('data/tmp_5927884634.parquet')

# %%
df['match_seq_num'].n_unique()
# Out:
# 8288

# %%
from scraping import request_matches

# %%
# %%time
df = request_matches(start_seq_num=5927884634, num_matches=15000, key=-1)
df
# Out:
# WARNING:root:Spamming dota API too fast on seq_num 5927885934
# WARNING:root:Spamming dota API too fast on seq_num 5927885934
# WARNING:root:Spamming dota API too fast on seq_num 5927885934
# WARNING:root:Spamming dota API too fast on seq_num 5927887034
# WARNING:root:Spamming dota API too fast on seq_num 5927887134
# WARNING:root:Spamming dota API too fast on seq_num 5927887134
# WARNING:root:Spamming dota API too fast on seq_num 5927887134
# WARNING:root:Spamming dota API too fast on seq_num 5927887134
# WARNING:root:Spamming dota API too fast on seq_num 5927888234
# WARNING:root:Spamming dota API too fast on seq_num 5927889234
# WARNING:root:Spamming dota API too fast on seq_num 5927889334
# WARNING:root:Spamming dota API too fast on seq_num 5927890234
# WARNING:root:Spamming dota API too fast on seq_num 5927890534
# WARNING:root:Spamming dota API too fast on seq_num 5927890534
# WARNING:root:Spamming dota API too fast on seq_num 5927890534
# WARNING:root:Spamming dota API too fast on seq_num 5927890534
# WARNING:root:Spamming dota API too fast on seq_num 5927890534
# WARNING:root:Spamming dota API too fast on seq_num 5927890534
# WARNING:root:Spamming dota API too fast on seq_num 5927891834
# WARNING:root:Spamming dota API too fast on seq_num 5927891834
# WARNING:root:Spamming dota API too fast on seq_num 5927891934
# WARNING:root:Spamming dota API too fast on seq_num 5927891934
# WARNING:root:Spamming dota API too fast on seq_num 5927893234
# WARNING:root:Spamming dota API too fast on seq_num 5927893234
# WARNING:root:Spamming dota API too fast on seq_num 5927893234
# WARNING:root:Spamming dota API too fast on seq_num 5927893934
# WARNING:root:Spamming dota API too fast on seq_num 5927894034
# WARNING:root:Spamming dota API too fast on seq_num 5927894034
# WARNING:root:Spamming dota API too fast on seq_num 5927894634
# WARNING:root:Spamming dota API too fast on seq_num 5927894834
# WARNING:root:Spamming dota API too fast on seq_num 5927894834
# WARNING:root:Spamming dota API too fast on seq_num 5927894934
# WARNING:root:Spamming dota API too fast on seq_num 5927895834
# WARNING:root:Spamming dota API too fast on seq_num 5927896034
# WARNING:root:Spamming dota API too fast on seq_num 5927896034
# WARNING:root:Spamming dota API too fast on seq_num 5927896034
# WARNING:root:Spamming dota API too fast on seq_num 5927896034
# WARNING:root:Spamming dota API too fast on seq_num 5927896034
# WARNING:root:Spamming dota API too fast on seq_num 5927896034
# WARNING:root:Spamming dota API too fast on seq_num 5927897534
# WARNING:root:Spamming dota API too fast on seq_num 5927897534
# WARNING:root:Spamming dota API too fast on seq_num 5927897534
# WARNING:root:Spamming dota API too fast on seq_num 5927898634
# WARNING:root:Spamming dota API too fast on seq_num 5927898734
# WARNING:root:Spamming dota API too fast on seq_num 5927898734
# CPU times: user 7.16 s, sys: 48.9 ms, total: 7.21 s
# Wall time: 14min 19s
#         match_id  match_seq_num  radiant_win  game_mode  start_time  duration  \
# 0     7059573908     5927884634        False         23  1678764028      1377
# 1     7059544777     5927884636        False         22  1678761197      4141
# 2     7059564435     5927884637         True         22  1678763121      2181
# 3     7059567671     5927884638        False         22  1678763422      1863
# 4     7059571166     5927884641        False         23  1678763758      1649
# ...          ...            ...          ...        ...         ...       ...
# 4311  7059593158     5927899685        False         23  1678765922      1120
# 4312  7059574818     5927899686        False         22  1678764098      2812
# 4313  7059580931     5927899691        False         22  1678764709      2217
# 4314  7059582075     5927899696        False         23  1678764829      2214
# 4315  7059582413     5927899697         True         23  1678764829      2178
#
#                           bans            radiant_team  \
# 0                           []   [26, 72, 113, 123, 8]
# 1             [46, 56, 10, 14]    [51, 138, 22, 74, 9]
# 2        [82, 113, 76, 44, 11]   [42, 136, 82, 14, 86]
# 3            [26, 82, 138, 56]     [51, 48, 2, 84, 76]
# 4                           []   [105, 59, 4, 71, 138]
# ...                        ...                     ...
# 4311                        []  [126, 80, 91, 44, 103]
# 4312  [29, 91, 136, 35, 76, 1]   [138, 9, 87, 32, 108]
# 4313                       [1]   [34, 41, 97, 119, 96]
# 4314                        []      [7, 13, 74, 2, 48]
# 4315                        []    [68, 119, 89, 58, 7]
#
#                    dire_team  num_leavers
# 0       [2, 27, 42, 11, 100]            0
# 1        [1, 50, 86, 14, 21]            0
# 2       [98, 35, 7, 100, 71]            0
# 3      [100, 86, 67, 30, 18]            0
# 4       [93, 123, 5, 64, 19]            1
# ...                      ...          ...
# 4311     [39, 17, 14, 1, 15]            0
# 4312    [136, 100, 8, 3, 31]            1
# 4313     [75, 21, 36, 8, 76]            0
# 4314  [67, 105, 12, 138, 11]            0
# 4315    [1, 47, 76, 32, 101]            0
#
# [14328 rows x 10 columns]

# %%
(df['radiant_win']).mean()
# Out:
# 0.5007334963325183

# %%
import requests 
import orjson 

msg = requests.get('http://api.steampowered.com/IDOTA2Match_570/GetMatchHistoryBySequenceNum/v1',
                   params={'start_at_match_seq_num': 5909520711,
                           'key': 'A6333E0CC31A3C6E18278FDB8F2AC983',
                           'matches_requested': 1})
msg_dict = orjson.loads(msg.text)
raw_matches = msg_dict['result']['matches']
raw_matches[0]['players'] = None
raw_matches[0]
# Out:
# {'players': None,
#  'radiant_win': True,
#  'duration': 2241,
#  'pre_game_duration': 90,
#  'start_time': 1677625148,
#  'match_id': 7038614936,
#  'match_seq_num': 5909520711,
#  'tower_status_radiant': 2047,
#  'tower_status_dire': 256,
#  'barracks_status_radiant': 63,
#  'barracks_status_dire': 48,
#  'cluster': 153,
#  'first_blood_time': 0,
#  'lobby_type': 7,
#  'human_players': 10,
#  'leagueid': 0,
#  'positive_votes': 0,
#  'negative_votes': 0,
#  'game_mode': 22,
#  'flags': 0,
#  'engine': 1,
#  'radiant_score': 56,
#  'dire_score': 34,
#  'picks_bans': [{'is_pick': True, 'hero_id': 62, 'team': 1, 'order': 0},
#   {'is_pick': True, 'hero_id': 35, 'team': 0, 'order': 1},
#   {'is_pick': True, 'hero_id': 42, 'team': 0, 'order': 2},
#   {'is_pick': True, 'hero_id': 50, 'team': 1, 'order': 3},
#   {'is_pick': True, 'hero_id': 11, 'team': 0, 'order': 4},
#   {'is_pick': True, 'hero_id': 105, 'team': 0, 'order': 5},
#   {'is_pick': True, 'hero_id': 21, 'team': 1, 'order': 6},
#   {'is_pick': True, 'hero_id': 84, 'team': 1, 'order': 7},
#   {'is_pick': True, 'hero_id': 72, 'team': 0, 'order': 8},
#   {'is_pick': True, 'hero_id': 6, 'team': 1, 'order': 9},
#   {'is_pick': False, 'hero_id': 14, 'team': 0, 'order': 10},
#   {'is_pick': False, 'hero_id': 1, 'team': 0, 'order': 11},
#   {'is_pick': False, 'hero_id': 67, 'team': 0, 'order': 12},
#   {'is_pick': False, 'hero_id': 76, 'team': 0, 'order': 13},
#   {'is_pick': False, 'hero_id': 75, 'team': 0, 'order': 14}]}

# %%
msg.status_code
# Out:
# 200

# %%
raw_matches[0]['picks_bans']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 raw_matches[0]['picks_bans']
#
# KeyError: 'picks_bans'

# %%
msg = requests.get('http://api.steampowered.com/IDOTA2Match_570/GetMatchHistory/v1',
                   params={# 'start_at_match_id': 7038629485,
                           'key': 'A6333E0CC31A3C6E18278FDB8F2AC983',
#                            'matches_requested': 100,
#                            'min_players': 10,
#                            'skill':2,
})
msg_dict = orjson.loads(msg.text)
raw_matches = msg_dict['result']['matches']
# raw_matches[0]['players'] = None
# raw_matches[0]

# %%
msg_dict
# Out:
# {'result': {'status': 1,
#   'num_results': 100,
#   'total_results': 500,
#   'results_remaining': 400,
#   'matches': [{'match_id': 7080181081,
#     'match_seq_num': 5945925836,
#     'start_time': 1679926857,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 354270378,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080180436,
#     'match_seq_num': 5945925509,
#     'start_time': 1679926822,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 110033432,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080179080,
#     'match_seq_num': 5945925921,
#     'start_time': 1679926786,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 22},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 44},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 2},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 64},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 26},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 47},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 29},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 8},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 5},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 37}]},
#    {'match_id': 7080178255,
#     'match_seq_num': 5945923478,
#     'start_time': 1679926741,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080177974,
#     'match_seq_num': 5945925326,
#     'start_time': 1679926746,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 5},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 6},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 26},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 8},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 21},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 44},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 37},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 35},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 14}]},
#    {'match_id': 7080177837,
#     'match_seq_num': 5945924160,
#     'start_time': 1679926742,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080177646,
#     'match_seq_num': 5945923756,
#     'start_time': 1679926725,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080177526,
#     'match_seq_num': 5945923378,
#     'start_time': 1679926706,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080176888,
#     'match_seq_num': 5945922780,
#     'start_time': 1679926702,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 116076382,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080176657,
#     'match_seq_num': 5945924222,
#     'start_time': 1679926681,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 1},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 96},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 26},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 66},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 44},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 36},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 18},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 5},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 111},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 53}]},
#    {'match_id': 7080175990,
#     'match_seq_num': 5945921464,
#     'start_time': 1679926667,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080175668,
#     'match_seq_num': 5945925601,
#     'start_time': 1679926666,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 44},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 29},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 22},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 26},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 14},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 47},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 31},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 21},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 8},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 5}]},
#    {'match_id': 7080175211,
#     'match_seq_num': 5945925207,
#     'start_time': 1679926650,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 26},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 14},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 8},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 22},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 2},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 35},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 20},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 5},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 47},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 6}]},
#    {'match_id': 7080175170,
#     'match_seq_num': 5945920972,
#     'start_time': 1679926648,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 316779439,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'account_id': 249293124,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080175152,
#     'match_seq_num': 5945922317,
#     'start_time': 1679926636,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080175007,
#     'match_seq_num': 5945922450,
#     'start_time': 1679926642,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 6},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 20},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 21},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 14},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 22},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 44},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 5},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 29},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 30}]},
#    {'match_id': 7080174808,
#     'match_seq_num': 5945920472,
#     'start_time': 1679926632,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080173224,
#     'match_seq_num': 5945923632,
#     'start_time': 1679926560,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 9},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 120},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 85},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 27},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 89},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 86},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 23},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 87},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 64},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 28}]},
#    {'match_id': 7080172547,
#     'match_seq_num': 5945918726,
#     'start_time': 1679926557,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080172465,
#     'match_seq_num': 5945923689,
#     'start_time': 1679926555,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 31},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 5},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 42},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 22},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 6},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 14},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 30},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 2},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 49},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 44}]},
#    {'match_id': 7080172170,
#     'match_seq_num': 5945923880,
#     'start_time': 1679926545,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 44},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 37},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 21},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 64},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 6},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 35},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 5},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 14}]},
#    {'match_id': 7080171899,
#     'match_seq_num': 5945921168,
#     'start_time': 1679926535,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 31},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 29},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 47},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 21},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 14},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 22},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 26},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 35},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 44},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 5}]},
#    {'match_id': 7080171312,
#     'match_seq_num': 5945924328,
#     'start_time': 1679926515,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 8},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 64},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 6},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 30},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 37},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 5},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 21},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 22}]},
#    {'match_id': 7080171295,
#     'match_seq_num': 5945917582,
#     'start_time': 1679926500,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 299938459,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080171237,
#     'match_seq_num': 5945923264,
#     'start_time': 1679926512,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 42},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 31},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 26},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 22},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 29},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 49},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 30},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 8},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 14},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 44}]},
#    {'match_id': 7080171125,
#     'match_seq_num': 5945919454,
#     'start_time': 1679926496,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080170755,
#     'match_seq_num': 5945925282,
#     'start_time': 1679926495,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 64},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 42},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 37},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 47},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 22},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 31},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 49},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 44},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 26},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 29}]},
#    {'match_id': 7080170201,
#     'match_seq_num': 5945917185,
#     'start_time': 1679926446,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080169894,
#     'match_seq_num': 5945920096,
#     'start_time': 1679926465,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 2},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 49},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 64},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 20},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 22},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 8},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 31},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 30}]},
#    {'match_id': 7080169768,
#     'match_seq_num': 5945918870,
#     'start_time': 1679926460,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 14},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 64},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 6},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 22},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 44},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 47},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 8},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 20},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 26}]},
#    {'match_id': 7080169055,
#     'match_seq_num': 5945916190,
#     'start_time': 1679926442,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080168273,
#     'match_seq_num': 5945918965,
#     'start_time': 1679926405,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 64},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 35},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 6},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 20},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 21},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 26},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 44},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 8},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 29}]},
#    {'match_id': 7080166734,
#     'match_seq_num': 5945919946,
#     'start_time': 1679926349,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 14},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 49},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 5},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 21},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 47},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 26},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 64},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 42},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 6},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 29}]},
#    {'match_id': 7080166539,
#     'match_seq_num': 5945924162,
#     'start_time': 1679926341,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 14},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 5},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 22},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 21},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 42},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 26},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 29},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 31},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 44}]},
#    {'match_id': 7080166534,
#     'match_seq_num': 5945913891,
#     'start_time': 1679926335,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080166422,
#     'match_seq_num': 5945913722,
#     'start_time': 1679926315,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 111161907,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080165765,
#     'match_seq_num': 5945913122,
#     'start_time': 1679926306,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080165499,
#     'match_seq_num': 5945923333,
#     'start_time': 1679926306,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 8},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 30},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 44},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 47},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 14},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 6},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 49},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 37},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 64}]},
#    {'match_id': 7080164931,
#     'match_seq_num': 5945915435,
#     'start_time': 1679926286,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 21},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 22},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 49},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 30},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 26},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 35},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 64},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 2},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 8},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 31}]},
#    {'match_id': 7080164902,
#     'match_seq_num': 5945915502,
#     'start_time': 1679926285,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 138},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 8},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 31},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 47},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 5},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 35},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 21},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 6},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 37},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 14}]},
#    {'match_id': 7080164166,
#     'match_seq_num': 5945915037,
#     'start_time': 1679926260,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 22},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 14},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 31},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 35},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 47},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 49},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 26},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 21},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 5}]},
#    {'match_id': 7080164136,
#     'match_seq_num': 5945925909,
#     'start_time': 1679926255,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 925225339,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 84},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 109},
#      {'account_id': 4294967295,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 33},
#      {'account_id': 1229150551,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 74},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 44},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 34},
#      {'account_id': 4294967295,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 95},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 9},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 14},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 121}]},
#    {'match_id': 7080164050,
#     'match_seq_num': 5945911693,
#     'start_time': 1679926256,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 0},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 0},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 0},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 0},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 0},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 0}]},
#    {'match_id': 7080163615,
#     'match_seq_num': 5945915673,
#     'start_time': 1679926240,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 6},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 22},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 8},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 20},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 37},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 14},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 35},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 31},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 44},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 42}]},
#    {'match_id': 7080163320,
#     'match_seq_num': 5945916124,
#     'start_time': 1679926230,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 44},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 20},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 29},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 6},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 5},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 2},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 14},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 26},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 47}]},
#    {'match_id': 7080162810,
#     'match_seq_num': 5945922209,
#     'start_time': 1679926209,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 138},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 35},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 14},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 64},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 21},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 49},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 42},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 37},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 29},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 26}]},
#    {'match_id': 7080162658,
#     'match_seq_num': 5945914873,
#     'start_time': 1679926205,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 5},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 31},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 21},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 44},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 22},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 30},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 29},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 64},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 42}]},
#    {'match_id': 7080162510,
#     'match_seq_num': 5945918246,
#     'start_time': 1679926199,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 35},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 2},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 30},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 37},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 42},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 5},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 22},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 47},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 6},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 31}]},
#    {'match_id': 7080162124,
#     'match_seq_num': 5945923555,
#     'start_time': 1679926186,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 22},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 31},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 37},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 29},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 42},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 26},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 8},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 14},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 2},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 44}]},
#    {'match_id': 7080161920,
#     'match_seq_num': 5945921230,
#     'start_time': 1679926171,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 11},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 22},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 20},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 42},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 7},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 8},
# ...
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 11},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 59},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 44},
#      {'account_id': 4294967295,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 100},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 47},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 10},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 64}]},
#    {'match_id': 7080154034,
#     'match_seq_num': 5945917330,
#     'start_time': 1679925875,
#     'lobby_type': 7,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 88940371,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 29},
#      {'account_id': 324323888,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 83},
#      {'account_id': 210673394,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 9},
#      {'account_id': 139454919,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 19},
#      {'account_id': 137203772,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 10},
#      {'account_id': 855501522,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 53},
#      {'account_id': 297490928,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 43},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 82},
#      {'account_id': 430384414,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 77},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 64}]},
#    {'match_id': 7080153902,
#     'match_seq_num': 5945924370,
#     'start_time': 1679925885,
#     'lobby_type': 7,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 873369466,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 102},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 47},
#      {'account_id': 144214338,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 44},
#      {'account_id': 4294967295,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 35},
#      {'account_id': 861149482,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 68},
#      {'account_id': 1012547399,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 72},
#      {'account_id': 345920665,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 76},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 1},
#      {'account_id': 245240209,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 137},
#      {'account_id': 207475215,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 26}]},
#    {'match_id': 7080153834,
#     'match_seq_num': 5945907187,
#     'start_time': 1679925889,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 29},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 64},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 2},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 8},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 31},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 21},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 14},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 20},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 47},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 42}]},
#    {'match_id': 7080153814,
#     'match_seq_num': 5945919045,
#     'start_time': 1679925875,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 113},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 91},
#      {'account_id': 4294967295,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 32},
#      {'account_id': 4294967295,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 15},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 107},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 78},
#      {'account_id': 4294967295,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 11},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 40},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 94},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 62}]},
#    {'match_id': 7080153732,
#     'match_seq_num': 5945923685,
#     'start_time': 1679925874,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 357814007,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 88},
#      {'account_id': 182736752,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 67},
#      {'account_id': 115933123,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 44},
#      {'account_id': 4294967295,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 78},
#      {'account_id': 149060011,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 84},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 86},
#      {'account_id': 934537711,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 59},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 27},
#      {'account_id': 157654924,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 114},
#      {'account_id': 104959742,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 52}]},
#    {'match_id': 7080153561,
#     'match_seq_num': 5945915244,
#     'start_time': 1679925865,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 1475399428,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 123},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 47},
#      {'account_id': 1248964715,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 52},
#      {'account_id': 4294967295,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 27},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 81},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 102},
#      {'account_id': 4294967295,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 138},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 44},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 97},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 104}]},
#    {'match_id': 7080153397,
#     'match_seq_num': 5945906877,
#     'start_time': 1679925860,
#     'lobby_type': 4,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 32},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 62},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 23},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 45},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 30},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 94},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 57},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 35},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 25},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 64}]},
#    {'match_id': 7080153197,
#     'match_seq_num': 5945914971,
#     'start_time': 1679925865,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 0},
#      {'player_slot': 0, 'team_number': 0, 'team_slot': 0, 'hero_id': 8},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 22},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 35},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 20},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 37},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 21},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 29},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 64},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 5}]},
#    {'match_id': 7080153144,
#     'match_seq_num': 5945919383,
#     'start_time': 1679925858,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 11},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 120},
#      {'account_id': 4294967295,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 1},
#      {'account_id': 1209942006,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 136},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 137},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 44},
#      {'account_id': 376223646,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 5},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 62},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 72},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 28}]},
#    {'match_id': 7080153063,
#     'match_seq_num': 5945918356,
#     'start_time': 1679925849,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 109},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 11},
#      {'account_id': 4294967295,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 46},
#      {'account_id': 4294967295,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 77},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 106},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 8},
#      {'account_id': 4294967295,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 72},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 52},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 61},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 36}]},
#    {'match_id': 7080152901,
#     'match_seq_num': 5945922330,
#     'start_time': 1679925850,
#     'lobby_type': 0,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'account_id': 4294967295,
#       'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 14},
#      {'account_id': 4294967295,
#       'player_slot': 1,
#       'team_number': 0,
#       'team_slot': 1,
#       'hero_id': 138},
#      {'account_id': 4294967295,
#       'player_slot': 2,
#       'team_number': 0,
#       'team_slot': 2,
#       'hero_id': 26},
#      {'account_id': 4294967295,
#       'player_slot': 3,
#       'team_number': 0,
#       'team_slot': 3,
#       'hero_id': 7},
#      {'account_id': 4294967295,
#       'player_slot': 4,
#       'team_number': 0,
#       'team_slot': 4,
#       'hero_id': 27},
#      {'account_id': 4294967295,
#       'player_slot': 128,
#       'team_number': 1,
#       'team_slot': 0,
#       'hero_id': 5},
#      {'account_id': 4294967295,
#       'player_slot': 129,
#       'team_number': 1,
#       'team_slot': 1,
#       'hero_id': 1},
#      {'account_id': 4294967295,
#       'player_slot': 130,
#       'team_number': 1,
#       'team_slot': 2,
#       'hero_id': 6},
#      {'account_id': 4294967295,
#       'player_slot': 131,
#       'team_number': 1,
#       'team_slot': 3,
#       'hero_id': 57},
#      {'account_id': 4294967295,
#       'player_slot': 132,
#       'team_number': 1,
#       'team_slot': 4,
#       'hero_id': 41}]},
#    {'match_id': 7080152875,
#     'match_seq_num': 5945921117,
#     'start_time': 1679925854,
#     'lobby_type': 14,
#     'radiant_team_id': 0,
#     'dire_team_id': 0,
#     'players': [{'player_slot': 0,
#       'team_number': 0,
#       'team_slot': 0,
#       'hero_id': 14},
#      {'player_slot': 1, 'team_number': 0, 'team_slot': 1, 'hero_id': 8},
#      {'player_slot': 2, 'team_number': 0, 'team_slot': 2, 'hero_id': 26},
#      {'player_slot': 3, 'team_number': 0, 'team_slot': 3, 'hero_id': 29},
#      {'player_slot': 4, 'team_number': 0, 'team_slot': 4, 'hero_id': 35},
#      {'player_slot': 128, 'team_number': 1, 'team_slot': 0, 'hero_id': 64},
#      {'player_slot': 129, 'team_number': 1, 'team_slot': 1, 'hero_id': 20},
#      {'player_slot': 130, 'team_number': 1, 'team_slot': 2, 'hero_id': 47},
#      {'player_slot': 131, 'team_number': 1, 'team_slot': 3, 'hero_id': 21},
#      {'player_slot': 132, 'team_number': 1, 'team_slot': 4, 'hero_id': 6}]}]}}

# %%
7038629485
